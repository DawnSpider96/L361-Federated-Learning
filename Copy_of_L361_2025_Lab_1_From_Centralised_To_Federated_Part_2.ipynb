# %% [markdown]
# <a href="https://colab.research.google.com/github/DawnSpider96/L361-Federated-Learning/blob/release/Copy_of_L361_2025_Lab_1_From_Centralised_To_Federated_Part_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 0. Marking and Guidelines
# ---
# ***IMPORTANT***
#
# > The **attendance** and **active participation** in the **lab sessions** is **strongly recommended** and will be considered for grading.
# >
# > Save a copy of this notebook into your Drive before you start
# >
# > Please attempt all the **questions** marked for your **group** (Part II ✅ | Part III/MPhil ✅).
# >
# > Please, provide your answers in a **new cell below the question cell**. You can make as many new cells as you need.
#
# Please submit a `.zip` file, containing both parts, consisting of:
# 1. A text file with a **publicly** visible link to your notebooks in GitHub.
# 2. A **downloaded copy** (`.ipynb`) of your notebooks or your zipped cloned GitHub repo. You may treat these as a report---we will not be re-executing the code you used to produce the answers unless required.
#
#
# Feel free to attempt more in case you find yourself enjoying the material!
# If you have any questions, please ask them to the teaching assistants.
# Are you interested in knowing more about federated learning and related topics? Reach out to the teaching assistants for additional resources and ask more about the current research projects.

# %% [markdown]
# ## Dependencies
# ---

# %%
# `pip` could produce some errors. Do not worry about them.
# The execution has been verified; it's working anyway.
! pip install --quiet --upgrade "pip"
! pip install --quiet matplotlib tqdm seaborn
! pip install git+https://github.com/Iacob-Alexandru-Andrei/flower.git@teaching \
    torch torchvision ray=="2.6.3"

# %% [markdown]
# ### Imports.

# %%
import random
from pathlib import Path
import tarfile
from typing import Any
from logging import INFO
from collections import defaultdict, OrderedDict
from collections.abc import Sequence, Callable
import numbers

import numpy as np
import torch
from torch import nn
from torch.nn import Module
from torch.utils.data import DataLoader, Dataset
from enum import IntEnum
import flwr
from flwr.server import History, ServerConfig
from flwr.server.strategy import FedAvgM as FedAvg, Strategy
from flwr.common import log, NDArrays, Scalar, Parameters, ndarrays_to_parameters
from flwr.client.client import Client

from common.client_utils import (
    Net,
    load_femnist_dataset,
    get_network_generator_cnn as get_network_generator,
    train_femnist,
    test_femnist,
    save_history,
)


# Add new seeds here for easy autocomplete
class Seeds(IntEnum):
    """Seeds for reproducibility."""

    DEFAULT = 1337


np.random.seed(Seeds.DEFAULT)
random.seed(Seeds.DEFAULT)
torch.manual_seed(Seeds.DEFAULT)
torch.backends.cudnn.benchmark = False
torch.backends.cudnn.deterministic = True


PathType = Path | str | None


def get_device() -> str:
    """Get the device (cuda, mps, cpu)."""
    device = "cpu"
    if torch.cuda.is_available():
        device = "cuda"
    elif torch.backends.mps.is_available() and torch.backends.mps.is_built():
        device = "mps"
    return device

# %%
home_dir = Path.cwd()
dataset_dir: Path = home_dir / "femnist"
data_dir: Path = dataset_dir / "data"
centralized_partition: Path = dataset_dir / "client_data_mappings" / "centralized"
centralized_mapping: Path = dataset_dir / "client_data_mappings" / "centralized" / "0"
federated_partition: Path = dataset_dir / "client_data_mappings" / "fed_natural"

# Decompress dataset
if not dataset_dir.exists():
    with tarfile.open(home_dir / "femnist.tar.gz", "r:gz") as tar:
        tar.extractall(path=home_dir)
    log(INFO, "Dataset extracted in %s", dataset_dir)

# %% [markdown]
# ## 5. Building a Flower FL client.
# ---

# %% [markdown]
# Our first client abstraction shall be as simple as possible and will require adjustment to match the structure that the flower framework expects. However, it shall be conceptually identical and require only light API changes.

# %% [markdown]
# Moving from centralised ML to server-client FL requires us to provide a means of communication between the respective server and clients. The Flower Framework is ML-framework agnostic and allows various means of transmitting model parameters in the federated network. Since you may have limited resources in these labs, we will only tangentially follow the Flower framework while keeping the computational requirements to a minimum.
#
# The simplest and most common encoding for models is the mere transmission of model parameters as NumPy arrays instead of the stateful PyTorch models. The following functions allow for seamless conversions between the two.

# %%
def set_model_parameters(net: Module, parameters: NDArrays) -> Module:
    """Put a set of parameters into the model object.

    Parameters
    ----------
        net (Module): model object.
        parameters (NDArrays): set of parameters to put into the model.

    Returns
    -------
        Module: updated model object.
    """
    weights = parameters
    params_dict = zip(net.state_dict().keys(), weights, strict=False)
    state_dict = OrderedDict({k: torch.from_numpy(np.copy(v)) for k, v in params_dict})
    net.load_state_dict(state_dict, strict=True)
    return net


def get_model_parameters(net: Module) -> NDArrays:
    """Get the current model parameters as NDArrays.

    Parameters
    ----------
        net (Module): current model object.

    Returns
    -------
        NDArrays: set of parameters from the current model.
    """
    return [val.cpu().numpy() for _, val in net.state_dict().items()]

# %% [markdown]
# With them in place, making the client abstraction compatible with Flower requires only a bit of boilerplate such as allowing NumPy arrays to be received and sent instead of PyTorch models. To achieve this, we provide a model generator capable of creating a network and using the received parameters.
#
# To keep client objects light in the memory when not used by the Flower FL simulator, the model generator is only called as needed for either `fit` or `evaluate`.

# %%
class FlowerRayClient(flwr.client.NumPyClient):
    """Flower client for the FEMNIST dataset."""

    def __init__(
        self,
        cid: int,
        partition_dir: Path,
        model_generator: Callable[[], Module],
    ) -> None:
        """Init the client with its unique id and the folder to load data from.

        Parameters
        ----------
            cid (int): Unique client id for a client used to map it to its data
                partition
            partition_dir (Path): The directory containing data for each
                client/client id
            model_generator (Callable[[], Module]): The model generator function
        """
        self.cid = cid
        log(INFO, "cid: %s", self.cid)
        self.partition_dir = partition_dir
        self.device = str(
            torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
        )
        self.model_generator: Callable[[], Module] = model_generator
        self.properties: dict[str, Scalar] = {"tensor_type": "numpy.ndarray"}

    def set_parameters(self, parameters: NDArrays) -> Module:
        """Load weights inside the network.

        Parameters
        ----------
            parameters (NDArrays): set of weights to be loaded.

        Returns
        -------
            [Module]: Network with new set of weights.
        """
        net = self.model_generator()
        return set_model_parameters(net, parameters)

    def get_parameters(self, config: dict[str, Scalar]) -> NDArrays:
        """Return weights from a given model.

        If no model is passed, then a local model is created.
        This can be used to initialise a model in the
        server.
        The config param is not used but is mandatory in Flower.

        Parameters
        ----------
            config (dict[int, Scalar]): dictionary containing configuration info.

        Returns
        -------
            NDArrays: weights from the model.
        """
        net = self.model_generator()
        return get_model_parameters(net)

    def fit(
        self, parameters: NDArrays, config: dict[str, Scalar]
    ) -> tuple[NDArrays, int, dict]:
        """Receive and train a model on the local client data.

        It uses parameters from the config dict

        Parameters
        ----------
            net (NDArrays): Pytorch model parameters
            config (dict[str, Scalar]): dictionary describing the training parameters

        Returns
        -------
            tuple[NDArrays, int, dict]: Returns the updated model, the size of the local
                dataset and other metrics
        """
        # Only create model right before training/testing
        # To lower memory usage when idle
        net = self.set_parameters(parameters)
        net.to(self.device)

        train_loader: DataLoader = self._create_data_loader(config, name="train")
        train_loss = self._train(net, train_loader=train_loader, config=config)
        return get_model_parameters(net), len(train_loader), {"train_loss": train_loss}

    def evaluate(
        self, parameters: NDArrays, config: dict[str, Scalar]
    ) -> tuple[float, int, dict]:
        """Receive and test a model on the local client data.

        It uses parameters from the config dict

        Parameters
        ----------
            net (NDArrays): Pytorch model parameters
            config (dict[str, Scalar]): dictionary describing the testing parameters

        Returns
        -------
            tuple[float, int, dict]: Returns the loss accumulate during testing, the
                size of the local dataset and other metrics such as accuracy
        """
        net = self.set_parameters(parameters)
        net.to(self.device)

        test_loader: DataLoader = self._create_data_loader(config, name="test")
        loss, accuracy = self._test(net, test_loader=test_loader, config=config)
        return loss, len(test_loader), {"local_accuracy": accuracy}

    def _create_data_loader(self, config: dict[str, Scalar], name: str) -> DataLoader:
        """Create the data loader using the specified config parameters.

        Parameters
        ----------
            config (dict[str, Scalar]): dictionary containing dataloader and dataset
                parameters
            mode (str): Load the training or testing set for the client

        Returns
        -------
            DataLoader: A pytorch dataloader iterable for training/testing
        """
        batch_size = int(config["batch_size"])
        num_workers = int(config["num_workers"])
        dataset = self._load_dataset(name)
        return DataLoader(
            dataset=dataset,
            batch_size=batch_size,
            shuffle=True,
            num_workers=num_workers,
            drop_last=(name == "train"),
        )

    def _load_dataset(self, name: str) -> Dataset:
        full_file: Path = self.partition_dir / str(self.cid)
        return load_femnist_dataset(
            mapping=full_file,
            name=name,
            data_dir=data_dir,
        )

    def _train(
        self, net: Module, train_loader: DataLoader, config: dict[str, Scalar]
    ) -> float:
        return train_femnist(
            net=net,
            train_loader=train_loader,
            epochs=int(config["epochs"]),
            device=self.device,
            optimizer=torch.optim.AdamW(
                net.parameters(),
                lr=float(config["client_learning_rate"]),
                weight_decay=float(config["weight_decay"]),
            ),
            criterion=torch.nn.CrossEntropyLoss(),
            max_batches=int(config["max_batches"]),
        )

    def _test(
        self, net: Module, test_loader: DataLoader, config: dict[str, Scalar]
    ) -> tuple[float, float]:
        return test_femnist(
            net=net,
            test_loader=test_loader,
            device=self.device,
            criterion=torch.nn.CrossEntropyLoss(),
            max_batches=int(config["max_batches"]),
        )

    def get_properties(self, config: dict[str, Scalar]) -> dict[str, Scalar]:
        """Return properties for this client.

        Parameters
        ----------
            config (dict[str, Scalar]): Options to be used for selecting specific
            properties.

        Returns
        -------
            dict[str, Scalar]: Returned properties.
        """
        return self.properties

    def get_train_set_size(self) -> int:
        """Return the client train set size.

        Returns
        -------
            int: train set size of the client.
        """
        return len(self._load_dataset("train"))  # type: ignore[reportArgumentType]

    def get_test_set_size(self) -> int:
        """Return the client test set size.

        Returns
        -------
            int: test set size of the client.
        """
        return len(self._load_dataset("test"))  # type: ignore[reportArgumentType]


def fit_client_seeded(
    client: FlowerRayClient,
    params: NDArrays,
    conf: dict[str, Any],
    seed: Seeds = Seeds.DEFAULT,
    **kwargs: Any,
) -> tuple[NDArrays, int, dict]:
    """Wrap to always seed client training."""
    np.random.seed(seed)
    torch.manual_seed(seed)
    random.seed(seed)
    return client.fit(params, conf, **kwargs)

# %% [markdown]
# The underlying FL simulator used by Flower is based on [Ray](https://www.ray.io/). It expects each client only to require a client ID for instantiation. Therefore, using the following generator function, we can determine the specific network used for FL together with the FEMNIST partition to which the `cid` refers.
#
# While we will not use `Ray` in this lab due to its heavyweight nature, we will keep all code API compatible with the default flower framework.

# %%
def get_flower_client_generator(
    model_generator: Callable[[], Module],
    partition_dir: Path,
    mapping_fn: Callable[[int], int] | None = None,
) -> Callable[[str], FlowerRayClient]:
    """Wrap the client instance generator.

    This provides the client generator with a model generator function.
    Also, the partition directory must be passed.
    A mapping function could be used for filtering/ordering clients.

    Parameters
    ----------
        model_generator (Callable[[], Module]): model generator function.
        partition_dir (Path): directory containing the partition.
        mapping_fn (Optional[Callable[[int], int]]): function mapping sorted/filtered
            ids to real cid.

    Returns
    -------
        Callable[[str], FlowerRayClient]: client instance.
    """

    def client_fn(cid: str) -> FlowerRayClient:
        """Create a single client instance given the client id `cid`.

        Parameters
        ----------
            cid (str): client id, Flower requires this to be of type str.

        Returns
        -------
            FlowerRayClient: client instance.
        """
        return FlowerRayClient(
            cid=mapping_fn(int(cid)) if mapping_fn is not None else int(cid),
            partition_dir=partition_dir,
            model_generator=model_generator,
        )

    return client_fn

# %% [markdown]
# To ensure the Flower client behaves the same as our simple demo client, a simple test using the centralised partition we defined earlier should suffice.

# %%
network_generator = get_network_generator()
seed_net: Net = network_generator()
seed_model_params: NDArrays = get_model_parameters(seed_net)

centralized_flower_client_generator: Callable[[str], FlowerRayClient] = (
    get_flower_client_generator(network_generator, centralized_partition)
)
centralized_flower_client = centralized_flower_client_generator(str(0))
# Out:
# INFO flwr 2025-02-09 22:32:32,353 | <ipython-input-60-2c3670f7beb9>:21 | cid: 0
# INFO:flwr:cid: 0

# %%
centralized_train_config: dict[str, Any] = {
    "epochs": 1,
    "batch_size": 32,
    "client_learning_rate": 0.01,
    "weight_decay": 0.001,
    "num_workers": 0,
    "max_batches": 100,
}

test_config: dict[str, Any] = {
    "batch_size": 32,
    "num_workers": 0,
    "max_batches": 100,
}

# Train parameters on the centralised dataset
trained_params, num_examples, train_metrics = fit_client_seeded(
    centralized_flower_client, params=seed_model_params, conf=centralized_train_config
)
log(INFO, "Train Metrics = %s", train_metrics)
# Out:
# /content/common/femnist_dataset.py:98: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(preprocessed_path)
# INFO flwr 2025-02-09 22:32:33,855 | <ipython-input-63-63f637b1e36d>:20 | Train Metrics = {'train_loss': 0.11736484438180923}
# INFO:flwr:Train Metrics = {'train_loss': 0.11736484438180923}

# %%
# Test trained parameters on the centralised dataset
loss, num_examples, test_metrics = centralized_flower_client.evaluate(
    parameters=trained_params, config=test_config
)
log(INFO, "Loss = %s; Test Metrics = %s", loss, test_metrics)
# Out:
#   4%|▍         | 100/2329 [00:00<00:20, 111.26it/s]
# INFO flwr 2025-02-09 22:32:34,807 | <ipython-input-64-5591b8433db2>:5 | Loss = 369.5744831562042; Test Metrics = {'local_accuracy': 0.059375}
# INFO:flwr:Loss = 369.5744831562042; Test Metrics = {'local_accuracy': 0.059375}

# %% [markdown]
# ## 6. FL with natural partitions
# ---

# %% [markdown]
# Given its naturally-partitioned nature, we can easily construct a realistic FL experiment by mapping clients one-to-one with the writers of the original symbols.
#
# To pursue this aim, we shall use the “naturally federated” partition instead of the "centralised” one. We are then using the entire `train.csv` and `test.csv` contained in the subfolders of `client_data_mappings/fed_natural`. Each subfolder is named after the clients' ID in the dataset, i.e., from `0` to `3229`.
#
# To guarantee that each client has sufficient training data to participate meaningfully, a common practice is to set a lower bound on the number of samples a selected client is allowed to have. Generally, this threshold should be equivalent to at least one batch. We will now implement a function to sample clients from the federation that satisfies the abovementioned filter in the train set.

# %%
def sample_random_clients(
    total_clients: int,
    filter_less: int,
    partition: Path,
    seed: int | None = Seeds.DEFAULT,
) -> Sequence[int]:
    """Sample randomly clients.

    A filter on the client train set size is performed.

    Parameters
    ----------
        total_clients (int): total number of clients to sample.
        filter_less (int): max number of train samples for which the client is
            **discarded**.
        partition (Path): path to the folder containing the partitioning.
        seed (Optional[int], optional): seed for the random generator. Defaults to None.

    Returns
    -------
        Sequence[int]: list of sample client ids as int.
    """
    real_federated_cid_client_generator: Callable[[str], FlowerRayClient] = (
        get_flower_client_generator(network_generator, federated_partition)
    )
    if seed is not None:
        random.seed(seed)
    list_of_ids = []
    while len(list_of_ids) < total_clients:
        current_id = random.randint(0, 3229)
        if (
            real_federated_cid_client_generator(str(current_id)).get_train_set_size()
            > filter_less
        ):
            list_of_ids.append(current_id)
    return list_of_ids

# %% [markdown]
# While FEMNIST has more than 3000 clients, our small-scale experiments will not require more than 100 at any point.

# %%
total_clients: int = 100
list_of_ids = sample_random_clients(
    total_clients, centralized_train_config["batch_size"], federated_partition
)

federated_client_generator: Callable[[str], FlowerRayClient] = (
    get_flower_client_generator(
        network_generator, federated_partition, lambda seq_id: list_of_ids[seq_id]
    )
)
# Out:
# INFO flwr 2025-02-09 22:32:34,820 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2530
# INFO:flwr:cid: 2530
# INFO flwr 2025-02-09 22:32:34,823 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2184
# INFO:flwr:cid: 2184
# INFO flwr 2025-02-09 22:32:34,825 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2907
# INFO:flwr:cid: 2907
# INFO flwr 2025-02-09 22:32:34,828 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1498
# INFO:flwr:cid: 1498
# INFO flwr 2025-02-09 22:32:34,830 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2338
# INFO:flwr:cid: 2338
# INFO flwr 2025-02-09 22:32:34,833 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2399
# INFO:flwr:cid: 2399
# INFO flwr 2025-02-09 22:32:34,835 | <ipython-input-60-2c3670f7beb9>:21 | cid: 
| <ipython-input-60-2c3670f7beb9>:21 | cid: 2274
# INFO:flwr:cid: 2274
# INFO flwr 2025-02-09 22:32:35,046 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2975
# INFO:flwr:cid: 2975
# INFO flwr 2025-02-09 22:32:35,049 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2645
# INFO:flwr:cid: 2645
# INFO flwr 2025-02-09 22:32:35,052 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1258
# INFO:flwr:cid: 1258
# INFO flwr 2025-02-09 22:32:35,054 | <ipython-input-60-2c3670f7beb9>:21 | cid: 875
# INFO:flwr:cid: 875
# INFO flwr 2025-02-09 22:32:35,057 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2504
# INFO:flwr:cid: 2504
# INFO flwr 2025-02-09 22:32:35,060 | <ipython-input-60-2c3670f7beb9>:21 | cid: 740
# INFO:flwr:cid: 740
# INFO flwr 2025-02-09 22:32:35,062 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2167
# INFO:flwr:cid: 2167
# INFO flwr 2025-02-09 22:32:35,065 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2157
# INFO:flwr:cid: 2157
# INFO flwr 2025-02-09 22:32:35,068 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2164
# INFO:flwr:cid: 2164
# INFO flwr 2025-02-09 22:32:35,072 | <ipython-input-60-2c3670f7beb9>:21 | cid: 757
# INFO:flwr:cid: 757
# INFO flwr 2025-02-09 22:32:35,076 | <ipython-input-60-2c3670f7beb9>:21 | cid: 3175
# INFO:flwr:cid: 3175
# INFO flwr 2025-02-09 22:32:35,079 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2714
# INFO:flwr:cid: 2714
# INFO flwr 2025-02-09 22:32:35,081 | <ipython-input-60-2c3670f7beb9>:21 | cid: 206
# INFO:flwr:cid: 206
# INFO flwr 2025-02-09 22:32:35,084 | <ipython-input-60-2c3670f7beb9>:21 | cid: 3057
# INFO:flwr:cid: 3057
# INFO flwr 2025-02-09 22:32:35,087 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2026
# INFO:flwr:cid: 2026
# INFO flwr 2025-02-09 22:32:35,090 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2882
# INFO:flwr:cid: 2882

# %% [markdown]
# Now, to test that the newly partitioned clients can be trained.

# %%
# one_epoch_config: dict[str, Any] = {
#     "epochs": 1,
#     "batch_size": 32,
#     "client_learning_rate": 0.01,
#     "weight_decay": 0.001,
#     "num_workers": 0,
#     "max_batches": 100,
# }

test_config: dict[str, Any] = {
    "batch_size": 32,
    "num_workers": 0,
    "max_batches": 100,
}

# %% [markdown]
# Modified the code slightly to preserve the constructed clients. Such that federated_client_generator is called only 4 times.
#
# This was for Question 5 part 3.

# %%
num_clients = 4
clientIds = random.sample(list(range(total_clients)), num_clients)
clients = [federated_client_generator(str(cid)) for cid in clientIds]
print(f'{clients=}')
# Out:
# INFO flwr 2025-02-09 22:32:35,104 | <ipython-input-60-2c3670f7beb9>:21 | cid: 3175
# INFO:flwr:cid: 3175
# INFO flwr 2025-02-09 22:32:35,106 | <ipython-input-60-2c3670f7beb9>:21 | cid: 51
# INFO:flwr:cid: 51
# INFO flwr 2025-02-09 22:32:35,109 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1668
# INFO:flwr:cid: 1668
# INFO flwr 2025-02-09 22:32:35,111 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1498
# INFO:flwr:cid: 1498
# clients=[<__main__.FlowerRayClient object at 0x78d10442af10>, <__main__.FlowerRayClient object at 0x78d107fb1c50>, <__main__.FlowerRayClient object at 0x78d104481410>, <__main__.FlowerRayClient object at 0x78d107fdded0>]

# %%
def train(clients, numEpoch):
    epoch_config: dict[str, Any] = {
    "epochs": numEpoch,
    "batch_size": 32,
    "client_learning_rate": 0.01,
    "weight_decay": 0.001,
    "num_workers": 0,
    "max_batches": 100,
    }

    trained_models_1Epoch = [
    fit_client_seeded(
        client, seed_model_params, epoch_config
    )
    for client in clients
    ]

    params = [model for model, *rest in trained_models_1Epoch]
    metrics = [rest for _, *rest in trained_models_1Epoch]
    log(INFO, "Metrics from trained models are: %s", metrics)
    return params, metrics

# %% [markdown]
# Added configuration for 5 epochs (Question 5 part 3)

# %%
trained_model_parameters_1Epoch, trained_model_metrics_1Epoch = train(clients, 1)
trained_model_parameters_5Epoch, trained_model_metrics_5Epoch = train(clients, 5)
# Out:
# INFO flwr 2025-02-09 22:32:35,384 | <ipython-input-69-b33a0dd6045a>:20 | Metrics from trained models are: [[4, {'train_loss': 0.12444548681378365}], [11, {'train_loss': 0.12350443479689685}], [3, {'train_loss': 0.12324741234381993}], [4, {'train_loss': 0.12358860857784748}]]
# INFO:flwr:Metrics from trained models are: [[4, {'train_loss': 0.12444548681378365}], [11, {'train_loss': 0.12350443479689685}], [3, {'train_loss': 0.12324741234381993}], [4, {'train_loss': 0.12358860857784748}]]
# INFO flwr 2025-02-09 22:32:36,644 | <ipython-input-69-b33a0dd6045a>:20 | Metrics from trained models are: [[4, {'train_loss': 0.10080225579440594}], [11, {'train_loss': 0.11024788834831932}], [3, {'train_loss': 0.10799884796142578}], [4, {'train_loss': 0.09833855368196964}]]
# INFO:flwr:Metrics from trained models are: [[4, {'train_loss': 0.10080225579440594}], [11, {'train_loss': 0.11024788834831932}], [3, {'train_loss': 0.10799884796142578}], [4, {'train_loss': 0.09833855368196964}]]

# %% [markdown]
# ---
#
# **Question 5 (Part II ✅ | Part III/MPhil ✅):**
#
# (You need to provide the answer with **code** for this question. Written argumentation is **strongly** recommended.)
#
# If we index the weights of an ML model consecutively, with the assumed architecture being the same, we can visualize it as a single flattened 1-D vector. One, highly imperfect, metric for determining how similar two ML models are is cosine similarity. We can use this metric to compare the models our clients produce are.
#
# 1. Write functions to:
#     - Flatten the `NDArrays` objects into a single 1-D vector.
#     - Compute the cosine similarity of two 1-D vectors based on their inner product and norms.

# %%
def flatten(unevenWeights):
    """
    Flattens an (possibly uneven) NDArray into a single 1D vector.
    """
    return np.concatenate([item.flatten() for item in unevenWeights])

# %%
def cosineSimilarity(vec1, vec2):
    """
    Flattens 2 vectors to make them 1D, then
    computes their cosine similarity.
    """
    f1 = flatten(vec1)
    f2 = flatten(vec2)
    return np.dot(f1, f2) / np.linalg.norm(f1) / np.linalg.norm(f2)

# %% [markdown]
# 2. Compute a similarity matrix between all client models and plot it.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def plotSimilarityMatrix(similarityMatrix, numberEpochs, labels):
    sns.heatmap(similarityMatrix, annot=True, cmap="YlGnBu").set(
    xticklabels=labels,
    yticklabels=labels,
    title=f'Similarity for {numberEpochs} epoch(s)'
)

def computeSimilarityMatrix(models):
    """
    Computes the cosine similarity matrix for a list of client model weights.
    (After training.)

    First, flatten each model's weights into a 1D array.
    Then compute the cosine similarity between every pair of flattened models.
    Finally, stores the results in a matrix.

    Parameters:
        models (NDArray): List of trained models.

    Returns:
        similarityMatrix: 2D numpy array
        similarityMatrix(i, j) is similarity between the ith and jth model
    """
    flatModels = [flatten(model) for model in models]
    similarityMatrix = np.zeros((len(flatModels), len(flatModels)))
    for i in range(len(flatModels)):
        for j in range(len(flatModels)):
            similarityMatrix[i, j] = cosineSimilarity(flatModels[i], flatModels[j])
    return similarityMatrix

# %%
# One Epoch first
plotSimilarityMatrix(computeSimilarityMatrix(trained_model_parameters_1Epoch), 1, clientIds)

# %% [markdown]
# 3. What happens to the similarity matrix if you increase the number of local epochs that clients train for to 5 from 1? Why do you think that is?
# >You may want to save the parameters calculated here separately from the deault ones as both sets will be needed in future questions.

# %%
# 5 Epochs
plotSimilarityMatrix(computeSimilarityMatrix(trained_model_parameters_5Epoch), 5, clientIds)

# %% [markdown]
# 3. The local models train for more epochs on their respective training data subsets, causing the weights to diverge further from the initial shared model. In addition, there is no aggregation and synchronisation of local models to the aggregated weight deltas yet. Hence the similarity values (excluding diagonal) decreased.

# %% [markdown]
# ## 7. Federated training with Flower
# ---

# %% [markdown]
# The two basic blocks of synchronous server-client FL systems are:
# - A client with some local training method and data---i.e., SGD. This is what we have built thus far.
# - A server which coordinates training sends the federated model to clients at the start of each round and aggregates model updates at the end of each round.

# %% [markdown]
# ![picture](https://drive.google.com/uc?id=1Db_Uys2QPFHW6cMranZ_QXo2vC0A_C-N)

# %% [markdown]
# While the variety of client local training methods is as wide as ML, server training varies depending on which **aggregation algorithm** combines the model updates and forms the new federated model. Flower refers to the component that controls the aggregation and train/test configuration as a **strategy**. For our labs, strategy and aggregation algorithms will be used interchangeably.
#
# The strategy we shall use is [FedAvg](https://arxiv.org/abs/1602.05629):
#
# $G^{r+1} = G^{r} + \eta \left( \sum_{k=1}^{m} p_k G^r_k \right)$,
#
# where $G^{r+1}$ is the model for the next round, which is formed by applying a model update to the current round model $G^{r}$ weighted by the aggregation learning rate $\eta$. The model update is constructed by a sum of client models $G^{r}_k$ where each client model is weighted by $p_k$. The weight factor is usually set to $p_k = \tfrac{n_k}{N}$---the number of training examples held by said client divided by the example count of each client in the round $N = \sum_{k=1}^{m} n_k$.

# %% [markdown]
# ---
#
# **Question 7 (Part II ✅ | Part III/MPhil ✅):**
#
# (You need to provide the answer with **code** for this question. Written argumentation is **strongly** recommended.)
#
# Averaging models is meant to provide us with a reasonable compromise between the desired models of all clients involved. Given what you already know about the similarity of client models, we can test if this is true.
# 1. Write a function to compute the weighted average of two `NDArrays` objects while preserving the layer-structure. Use the FedAvg equation above with $p_k = \tfrac{n_k}{N}$.

# %%
def average(clientWeights, nks):
    """
    Computes the weighted average for each layer.

    This function iterates through all layers across all models.
    Then averages the deltas using np.average

    Parameters:
        clientWeights (NDArray): List of trained Models

    Returns:
        np.ndarray: List with the same shape as any input model,
                    containing the weights of the averaged model.
    """
    avg = []
    for layerIndex in range(len(clientWeights[0])):
        avg.append(np.average([cw[layerIndex] for cw in clientWeights], weights=nks, axis=0)
        )
    return avg

# %% [markdown]
# 2. Compute the average model of the client models above, both the one-epoch and multi-epoch ones.

# %%
nks = [client.get_train_set_size() for client in clients]
avg_1Epoch = average(trained_model_parameters_1Epoch, nks)
avg_5Epoch = average(trained_model_parameters_5Epoch, nks)
# Out:
# /content/common/femnist_dataset.py:98: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(preprocessed_path)

# %% [markdown]
# 3. Add the averaged models to the cosine-similarity matrices built above, how does it relate to the client models?

# %%
plotSimilarityMatrix(
    computeSimilarityMatrix(
        trained_model_parameters_1Epoch
        + [avg_1Epoch]
    ), 1, clientIds + ["average"]
)

# %%
plotSimilarityMatrix(
    computeSimilarityMatrix(
        trained_model_parameters_5Epoch
        + [avg_5Epoch]
    ), 1, clientIds + ["average"]
)

# %% [markdown]
# 3.
#
# Every individual model is more similar to the average than any other individual model. This makes intuitive sense because if we represent the models as vectors in N-dimensional space (which the computeSimilarityMatrix does by flattening the model weights), the average vector will be spatially in the middle of the other vectors.
#
# Following from Question 5 part 3, the 5 Epoch model weights diverged more than the 1 Epoch model weights, so naturally their average would be less similar than the 1 Epoch weights.

# %% [markdown]
# The pieces necessary for starting an FL simulation are now in play; we need to arrange them to fit the Flower API. First, we shall require a separate federated evaluation function which can be called outside the context of a specific client. It will use the centralised test set to be as simple as possible.

# %%
def get_federated_evaluation_function(
    batch_size: int,
    num_workers: int,
    model_generator: Callable[[], Module],
    criterion: Module,
    max_batches: int,
) -> Callable[[int, NDArrays, dict[str, Any]], tuple[float, dict[str, Scalar]]]:
    """Wrap the external federated evaluation function.

    It provides the external federated evaluation function with some
    parameters for the dataloader, the model generator function, and
    the criterion used in the evaluation.

    Parameters
    ----------
        batch_size (int): batch size of the test set to use.
        num_workers (int): correspond to `num_workers` param in the Dataloader object.
        model_generator (Callable[[], Module]):  model generator function.
        criterion (Module): PyTorch Module containing the criterion for evaluating the
        model.

    Returns
    -------
        Callable[[int, NDArrays, dict[str, Any]], tuple[float, dict[str, Scalar]]]:
            external federated evaluation function.
    """

    def federated_evaluation_function(
        server_round: int,
        parameters: NDArrays,
        fed_eval_config: dict[
            str, Any
        ],  # mandatory argument, even if it's not being used
    ) -> tuple[float, dict[str, Scalar]]:
        """Evaluate federated model on the server.

        It uses the centralized val set for sake of simplicity.

        Parameters
        ----------
            server_round (int): current federated round.
            parameters (NDArrays): current model parameters.
            fed_eval_config (dict[str, Any]): mandatory argument in Flower, can contain
                some configuration info

        Returns
        -------
            tuple[float, dict[str, Scalar]]: evaluation results
        """
        device: str = get_device()
        net: Module = set_model_parameters(model_generator(), parameters)
        net.to(device)

        full_file: Path = centralized_mapping
        dataset: Dataset = load_femnist_dataset(data_dir, full_file, "val")

        valid_loader = DataLoader(
            dataset=dataset,
            batch_size=batch_size,
            shuffle=False,
            num_workers=num_workers,
            drop_last=False,
        )

        loss, acc = test_femnist(
            net=net,
            test_loader=valid_loader,
            device=device,
            criterion=criterion,
            max_batches=max_batches,
        )
        return loss, {"accuracy": acc}

    return federated_evaluation_function


federated_evaluation_function = get_federated_evaluation_function(
    batch_size=test_config["batch_size"],
    num_workers=test_config["num_workers"],
    model_generator=network_generator,
    criterion=nn.CrossEntropyLoss(),
    max_batches=test_config["max_batches"],
)

# %%
def aggregate_weighted_average(metrics: list[tuple[int, dict]]) -> dict:
    """Combine results from multiple clients following training or evaluation.

    Parameters
    ----------
        metrics (list[tuple[int, dict]]): collected clients metrics

    Returns
    -------
        dict: result dictionary containing the aggregate of the metrics passed.
    """
    average_dict: dict = defaultdict(list)
    total_examples: int = 0
    for num_examples, metrics_dict in metrics:
        for key, val in metrics_dict.items():
            if isinstance(val, numbers.Number):
                average_dict[key].append((num_examples, val))
        total_examples += num_examples
    return {
        key: {
            "avg": float(
                sum([num_examples * metric for num_examples, metric in val])
                / float(total_examples)
            ),
            "all": val,
        }
        for key, val in average_dict.items()
    }

# %%
# Federated configuration dictionary
federated_train_config: dict[str, Any] = {
    "epochs": 5,
    "batch_size": 32,
    "client_learning_rate": 0.01,
    "weight_decay": 0.001,
    "num_workers": 0,
    "max_batches": 100,
}

# %% [markdown]
# The only challenge left is the FL simulation itself. In `Flower`, a `Server` object handles this for us by using `Ray` and spawning many heavyweight worker process.
#
# Given the limited-resource scenario in which we find ourselves, we provide you with a slightly modified simulation function which uses a simple thread pool. Feel free to swap it out for the original simulation or replace it with your own implementation if so inclined.
#
# > The server we use is not the default `Flower` server as it returns the model parameters from every single round in a `(round, NDArrays)` tuple.

# %%
def start_seeded_simulation(
    client_fn: Callable[[str], Client],
    num_clients: int,
    config: ServerConfig,
    strategy: Strategy,
    name: str,
    return_all_parameters: bool = False,
    seed: int = Seeds.DEFAULT,
    iteration: int = 0,
) -> tuple[list[tuple[int, NDArrays]], History]:
    """Wrap to seed client selection."""
    np.random.seed(seed ^ iteration)
    torch.manual_seed(seed ^ iteration)
    random.seed(seed ^ iteration)
    parameter_list, hist = flwr.simulation.start_simulation_no_ray(
        client_fn=client_fn,
        num_clients=num_clients,
        client_resources={},
        config=config,
        strategy=strategy,
    )
    save_history(home_dir, hist, name)
    return parameter_list, hist

# %%
num_rounds = 10

num_total_clients = 20

num_evaluate_clients = 0
num_clients_per_round = 5

initial_parameters = ndarrays_to_parameters(seed_model_params)


def run_simulation(
    # How long the FL process runs for:
    num_rounds: int = num_rounds,
    # Number of clients available
    num_total_clients: int = num_total_clients,
    # Number of clients used for train/eval
    num_clients_per_round: int = num_clients_per_round,
    num_evaluate_clients: int = num_evaluate_clients,
    # If less clients are overall available stop FL
    min_available_clients: int = num_total_clients,
    # If less clients are available for fit/eval stop FL
    min_fit_clients: int = num_clients_per_round,
    min_evaluate_clients: int = num_evaluate_clients,
    # Function to test the federated model performance
    # external to a client instantiation
    evaluate_fn: (
        Callable[
            [int, NDArrays, dict[str, Scalar]],
            tuple[float, dict[str, Scalar]] | None,
        ]
        | None
    ) = federated_evaluation_function,
    # Functions to generate a config for client fit/evaluate
    # by-default the same config is shallow-copied to all clients in Flower
    # this version simply uses the configs defined above
    on_fit_config_fn: Callable[
        [int], dict[str, Scalar]
    ] = lambda _x: federated_train_config,
    on_evaluate_config_fn: Callable[[int], dict[str, Scalar]] = lambda _x: test_config,
    # The "Parameters" type is merely a more packed version
    # of numpy array lists, used internally by Flower
    initial_parameters: Parameters = initial_parameters,
    # If this is set to True, aggregation will work even if some clients fail
    accept_failures: bool = False,
    # How to combine the metrics dictionary returned by all clients for fit/eval
    fit_metrics_aggregation_fn: Callable | None = aggregate_weighted_average,
    evaluate_metrics_aggregation_fn: Callable | None = aggregate_weighted_average,
    federated_client_generator: Callable[
        [str], flwr.client.NumPyClient
    ] = federated_client_generator,
    # Aggregation learning rate for FedAvg
    server_learning_rate: float = 1.0,
    server_momentum: float = 0.0,
) -> tuple[list[tuple[int, NDArrays]], History]:
    """Run a federated simulation using Flower."""
    log(INFO, "FL will execute for %s rounds", num_rounds)

    # Percentage of clients used for train/eval
    fraction_fit: float = float(num_clients_per_round) / num_total_clients
    fraction_evaluate: float = float(num_evaluate_clients) / num_total_clients

    strategy = FedAvg(
        fraction_fit=fraction_fit,
        fraction_evaluate=fraction_evaluate,
        min_fit_clients=min_fit_clients,
        min_evaluate_clients=min_evaluate_clients,
        min_available_clients=min_available_clients,
        on_fit_config_fn=on_fit_config_fn,
        on_evaluate_config_fn=on_evaluate_config_fn,
        evaluate_fn=evaluate_fn,
        initial_parameters=initial_parameters,
        accept_failures=accept_failures,
        fit_metrics_aggregation_fn=fit_metrics_aggregation_fn,
        evaluate_metrics_aggregation_fn=evaluate_metrics_aggregation_fn,
        server_learning_rate=server_learning_rate,
        server_momentum=server_momentum,
    )
    # resetting the seed for the random selection of clients
    # this way the list of clients trained is guaranteed to be always the same

    cfg = ServerConfig(num_rounds)

    def simulator_client_generator(cid: str) -> Client:
        return federated_client_generator(cid).to_client()

    parameters_for_each_round, hist = start_seeded_simulation(
        client_fn=simulator_client_generator,
        num_clients=num_total_clients,
        config=cfg,
        strategy=strategy,
        name="fedavg",
        return_all_parameters=True,
        seed=Seeds.DEFAULT,
    )
    return parameters_for_each_round, hist

# %%
parameters_for_each_round, hist = run_simulation()
# Out:
# INFO flwr 2025-02-09 22:32:50,730 | <ipython-input-84-ce7914585fee>:56 | FL will execute for 10 rounds
# INFO:flwr:FL will execute for 10 rounds
# INFO flwr 2025-02-09 22:32:50,734 | app.py:149 | Starting Flower simulation, config: ServerConfig(num_rounds=10, round_timeout=None)
# INFO:flwr:Starting Flower simulation, config: ServerConfig(num_rounds=10, round_timeout=None)
# INFO flwr 2025-02-09 22:32:50,736 | server_returns_parameters.py:81 | Initializing global parameters
# INFO:flwr:Initializing global parameters
# INFO flwr 2025-02-09 22:32:50,739 | server_returns_parameters.py:273 | Using initial parameters provided by strategy
# INFO:flwr:Using initial parameters provided by strategy
# INFO flwr 2025-02-09 22:32:50,744 | server_returns_parameters.py:84 | Evaluating initial parameters
# INFO:flwr:Evaluating initial parameters
# /content/common/femnist_dataset.py:98: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(preprocessed_path)
#  11%|█         | 100/891 [00:00<00:07, 110.12it/s]
# INFO flwr 2025-02-09 22:32:51,681 | server_returns_parameters.py:87 | initial parameters (loss, other metrics): 413.6843070983887, {'accuracy': 0.0065625}
# INFO:flwr:initial parameters (loss, other metrics): 413.6843070983887, {'accuracy': 0.0065625}
# INFO flwr 2025-02-09 22:32:51,683 | server_returns_parameters.py:97 | FL starting
# INFO:flwr:FL starting
# DEBUG flwr 2025-02-09 22:32:51,686 | server_returns_parameters.py:223 | fit_round 1: strategy sampled 5 clients (out of 20)
# DEBUG:flwr:fit_round 1: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-09 22:32:51,688 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1494
# INFO:flwr:cid: 1494
# INFO flwr 2025-02-09 22:32:51,689 | <ipython-input-60-2c3670f7beb9>:21 | cid: 3119
# INFO:flwr:cid: 3119
# INFO flwr 2025-02-09 22:32:51,693 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2600
# INFO:flwr:cid: 2600
# INFO flwr 2025-02-09 22:32:51,697 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2399
# INFO flwr 2025-02-09 22:32:51,699 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1571
# INFO:flwr:cid: 2399
# INFO:flwr:cid: 1571
# DEBUG flwr 2025-02-09 22:32:53,450 | server_returns_parameters.py:237 | fit_round 1 received 5 results and 0 failures
# DEBUG:flwr:fit_round 1 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 110.05it/s]
# INFO flwr 2025-02-09 22:32:54,388 | server_returns_parameters.py:120 | fit progress: (1, 360.1247637271881, {'accuracy': 0.069375}, 2.7024428369995803)
# INFO:flwr:fit progress: (1, 360.1247637271881, {'accuracy': 0.069375}, 2.7024428369995803)
# INFO flwr 2025-02-09 22:32:54,390 | server_returns_parameters.py:171 | evaluate_round 1: no clients selected, cancel
# INFO:flwr:evaluate_round 1: no clients selected, cancel
# DEBUG flwr 2025-02-09 22:32:54,392 | server_returns_parameters.py:223 | fit_round 2: strategy sampled 5 clients (out of 20)
# DEBUG:flwr:fit_round 2: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-09 22:32:54,395 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1473
# INFO:flwr:cid: 1473
# INFO flwr 2025-02-09 22:32:54,397 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2600
# INFO flwr 2025-02-09 22:32:54,401 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1363
# INFO:flwr:cid: 2600
# INFO:flwr:cid: 1363
# INFO flwr 2025-02-09 22:32:54,402 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1494
# INFO:flwr:cid: 1494
# INFO flwr 2025-02-09 22:32:54,402 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2997
# INFO:flwr:cid: 2997
# DEBUG flwr 2025-02-09 22:32:56,121 | server_returns_parameters.py:237 | fit_round 2 received 5 results and 0 failures
# DEBUG:flwr:fit_round 2 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 110.12it/s]
# INFO flwr 2025-02-09 22:32:57,059 | server_returns_parameters.py:120 | fit progress: (2, 340.95042634010315, {'accuracy': 0.079375}, 5.373267025999667)
# INFO:flwr:fit progress: (2, 340.95042634010315, {'accuracy': 0.079375}, 5.373267025999667)
# INFO flwr 2025-02-09 22:32:57,060 | server_returns_parameters.py:171 | evaluate_round 2: no clients selected, cancel
# INFO:flwr:evaluate_round 2: no clients selected, cancel
# DEBUG flwr 2025-02-09 22:32:57,062 | server_returns_parameters.py:223 | fit_round 3: strategy sampled 5 clients (out of 20)
# DEBUG:flwr:fit_round 3: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-09 22:32:57,066 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2600
# INFO:flwr:cid: 2600
# INFO flwr 2025-02-09 22:32:57,067 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1498
# INFO flwr 2025-02-09 22:32:57,070 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1260
# INFO:flwr:cid: 1498
# INFO flwr 2025-02-09 22:32:57,074 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1473
# INFO flwr 2025-02-09 22:32:57,075 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2907
# INFO:flwr:cid: 1260
# INFO:flwr:cid: 1473
# INFO:flwr:cid: 2907
# DEBUG flwr 2025-02-09 22:32:58,771 | server_returns_parameters.py:237 | fit_round 3 received 5 results and 0 failures
# DEBUG:flwr:fit_round 3 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 111.42it/s]
# INFO flwr 2025-02-09 22:32:59,699 | server_returns_parameters.py:120 | fit progress: (3, 347.0828287601471, {'accuracy': 0.074375}, 8.013329194000107)
# INFO:flwr:fit progress: (3, 347.0828287601471, {'accuracy': 0.074375}, 8.013329194000107)
# INFO flwr 2025-02-09 22:32:59,701 | server_returns_parameters.py:171 | evaluate_round 3: no clients selected, cancel
# INFO:flwr:evaluate_round 3: no clients selected, cancel
# DEBUG flwr 2025-02-09 22:32:59,703 | server_returns_parameters.py:223 | fit_round 4: strategy sampled 5 clients (out of 20)
# DEBUG:flwr:fit_round 4: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-09 22:32:59,707 | <ipython-input-60-2c3670f7beb9>:21 | cid: 839
# INFO:flwr:cid: 839
# INFO flwr 2025-02-09 22:32:59,707 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2600
# INFO:flwr:cid: 2600
# INFO flwr 2025-02-09 22:32:59,708 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1473
# INFO flwr 2025-02-09 22:32:59,709 | <ipython-input-60-2c3670f7beb9>:21 | cid: 3119
# INFO:flwr:cid: 1473
# INFO:flwr:cid: 3119
# INFO flwr 2025-02-09 22:32:59,712 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1363
# INFO:flwr:cid: 1363
# DEBUG flwr 2025-02-09 22:33:01,227 | server_returns_parameters.py:237 | fit_round 4 received 5 results and 0 failures
# DEBUG:flwr:fit_round 4 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 111.22it/s]
# INFO flwr 2025-02-09 22:33:02,156 | server_returns_parameters.py:120 | fit progress: (4, 339.16271901130676, {'accuracy': 0.074375}, 10.470215270000153)
# INFO:flwr:fit progress: (4, 339.16271901130676, {'accuracy': 0.074375}, 10.470215270000153)
# INFO flwr 2025-02-09 22:33:02,157 | server_returns_parameters.py:171 | evaluate_round 4: no clients selected, cancel
# INFO:flwr:evaluate_round 4: no clients selected, cancel
# DEBUG flwr 2025-02-09 22:33:02,161 | server_returns_parameters.py:223 | fit_round 5: strategy sampled 5 clients (out of 20)
# DEBUG:flwr:fit_round 5: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-09 22:33:02,163 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2530
# INFO:flwr:cid: 2530
# INFO flwr 2025-02-09 22:33:02,163 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2600
# INFO:flwr:cid: 2600
# INFO flwr 2025-02-09 22:33:02,165 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1498
# INFO flwr 2025-02-09 22:33:02,169 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1603
# INFO:flwr:cid: 1498
# INFO flwr 2025-02-09 22:33:02,171 | <ipython-input-60-2c3670f7beb9>:21 | cid: 678
# INFO:flwr:cid: 1603
# INFO:flwr:cid: 678
# DEBUG flwr 2025-02-09 22:33:03,943 | server_returns_parameters.py:237 | fit_round 5 received 5 results and 0 failures
# DEBUG:flwr:fit_round 5 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 110.78it/s]
# INFO flwr 2025-02-09 22:33:04,875 | server_returns_parameters.py:120 | fit progress: (5, 320.6300916671753, {'accuracy': 0.19125}, 13.189461270999345)
# INFO:flwr:fit progress: (5, 320.6300916671753, {'accuracy': 0.19125}, 13.189461270999345)
# INFO flwr 2025-02-09 22:33:04,876 | server_returns_parameters.py:171 | evaluate_round 5: no clients selected, cancel
# INFO:flwr:evaluate_round 5: no clients selected, cancel
# DEBUG flwr 2025-02-09 22:33:04,878 | server_returns_parameters.py:223 | fit_round 6: strategy sampled 5 clients (out of 20)
# DEBUG:flwr:fit_round 6: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-09 22:33:04,882 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2399
# INFO:flwr:cid: 2399
# INFO flwr 2025-02-09 22:33:04,882 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1571
# INFO:flwr:cid: 1571
# INFO flwr 2025-02-09 22:33:04,883 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1603
# INFO:flwr:cid: 1603
# INFO flwr 2025-02-09 22:33:04,886 | <ipython-input-60-2c3670f7beb9>:21 | cid: 3175
# INFO:flwr:cid: 3175
# INFO flwr 2025-02-09 22:33:04,886 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2997
# INFO:flwr:cid: 2997
# DEBUG flwr 2025-02-09 22:33:06,539 | server_returns_parameters.py:237 | fit_round 6 received 5 results and 0 failures
# DEBUG:flwr:fit_round 6 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 108.56it/s]
# INFO flwr 2025-02-09 22:33:07,491 | server_returns_parameters.py:120 | fit progress: (6, 296.1859288215637, {'accuracy': 0.2271875}, 15.805660957999862)
# INFO:flwr:fit progress: (6, 296.1859288215637, {'accuracy': 0.2271875}, 15.805660957999862)
# INFO flwr 2025-02-09 22:33:07,493 | server_returns_parameters.py:171 | evaluate_round 6: no clients selected, cancel
# INFO:flwr:evaluate_round 6: no clients selected, cancel
# DEBUG flwr 2025-02-09 22:33:07,496 | server_returns_parameters.py:223 | fit_round 7: strategy sampled 5 clients (out of 20)
# DEBUG:flwr:fit_round 7: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-09 22:33:07,499 | <ipython-input-60-2c3670f7beb9>:21 | cid: 3119
# INFO:flwr:cid: 3119
# INFO flwr 2025-02-09 22:33:07,501 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2907
# INFO flwr 2025-02-09 22:33:07,501 | <ipython-input-60-2c3670f7beb9>:21 | cid: 839
# INFO:flwr:cid: 2907
# INFO:flwr:cid: 839
# INFO flwr 2025-02-09 22:33:07,509 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2184
# INFO:flwr:cid: 2184
# INFO flwr 2025-02-09 22:33:07,514 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2688
# INFO:flwr:cid: 2688
# DEBUG flwr 2025-02-09 22:33:09,156 | server_returns_parameters.py:237 | fit_round 7 received 5 results and 0 failures
# DEBUG:flwr:fit_round 7 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 110.20it/s]
# INFO flwr 2025-02-09 22:33:10,095 | server_returns_parameters.py:120 | fit progress: (7, 272.9338494539261, {'accuracy': 0.26625}, 18.40921241199976)
# INFO:flwr:fit progress: (7, 272.9338494539261, {'accuracy': 0.26625}, 18.40921241199976)
# INFO flwr 2025-02-09 22:33:10,097 | server_returns_parameters.py:171 | evaluate_round 7: no clients selected, cancel
# INFO:flwr:evaluate_round 7: no clients selected, cancel
# DEBUG flwr 2025-02-09 22:33:10,099 | server_returns_parameters.py:223 | fit_round 8: strategy sampled 5 clients (out of 20)
# DEBUG:flwr:fit_round 8: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-09 22:33:10,100 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1260
# INFO:flwr:cid: 1260
# INFO flwr 2025-02-09 22:33:10,101 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2184
# INFO:flwr:cid: 2184
# INFO flwr 2025-02-09 22:33:10,104 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2530
# INFO:flwr:cid: 2530
# INFO flwr 2025-02-09 22:33:10,108 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2997
# INFO flwr 2025-02-09 22:33:10,110 | <ipython-input-60-2c3670f7beb9>:21 | cid: 839
# INFO:flwr:cid: 2997
# INFO:flwr:cid: 839
# DEBUG flwr 2025-02-09 22:33:12,076 | server_returns_parameters.py:237 | fit_round 8 received 5 results and 0 failures
# DEBUG:flwr:fit_round 8 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 109.06it/s]
# INFO flwr 2025-02-09 22:33:13,022 | server_returns_parameters.py:120 | fit progress: (8, 259.0822528600693, {'accuracy': 0.346875}, 21.337089324999397)
# INFO:flwr:fit progress: (8, 259.0822528600693, {'accuracy': 0.346875}, 21.337089324999397)
# INFO flwr 2025-02-09 22:33:13,024 | server_returns_parameters.py:171 | evaluate_round 8: no clients selected, cancel
# INFO:flwr:evaluate_round 8: no clients selected, cancel
# DEBUG flwr 2025-02-09 22:33:13,026 | server_returns_parameters.py:223 | fit_round 9: strategy sampled 5 clients (out of 20)
# DEBUG:flwr:fit_round 9: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-09 22:33:13,028 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1498
# INFO:flwr:cid: 1498
# INFO flwr 2025-02-09 22:33:13,029 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1363
# INFO:flwr:cid: 1363
# INFO flwr 2025-02-09 22:33:13,032 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2997
# INFO flwr 2025-02-09 22:33:13,036 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1603
# INFO:flwr:cid: 2997
# INFO flwr 2025-02-09 22:33:13,040 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1571
# INFO:flwr:cid: 1603
# INFO:flwr:cid: 1571
# DEBUG flwr 2025-02-09 22:33:14,641 | server_returns_parameters.py:237 | fit_round 9 received 5 results and 0 failures
# DEBUG:flwr:fit_round 9 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 109.05it/s]
# INFO flwr 2025-02-09 22:33:15,588 | server_returns_parameters.py:120 | fit progress: (9, 252.99339151382446, {'accuracy': 0.3846875}, 23.90210134999961)
# INFO:flwr:fit progress: (9, 252.99339151382446, {'accuracy': 0.3846875}, 23.90210134999961)
# INFO flwr 2025-02-09 22:33:15,589 | server_returns_parameters.py:171 | evaluate_round 9: no clients selected, cancel
# INFO:flwr:evaluate_round 9: no clients selected, cancel
# DEBUG flwr 2025-02-09 22:33:15,591 | server_returns_parameters.py:223 | fit_round 10: strategy sampled 5 clients (out of 20)
# DEBUG:flwr:fit_round
# INFO:flwr:app_fit: losses_centralized [(0, 413.6843070983887), (1, 360.1247637271881), (2, 340.95042634010315), (3, 347.0828287601471), (4, 339.16271901130676), (5, 320.6300916671753), (6, 296.1859288215637), (7, 272.9338494539261), (8, 259.0822528600693), (9, 252.99339151382446), (10, 249.8600766658783)]
# INFO flwr 2025-02-09 22:33:18,529 | app.py:254 | app_fit: metrics_centralized {'accuracy': [(0, 0.0065625), (1, 0.069375), (2, 0.079375), (3, 0.074375), (4, 0.074375), (5, 0.19125), (6, 0.2271875), (7, 0.26625), (8, 0.346875), (9, 0.3846875), (10, 0.3671875)]}
# INFO:flwr:app_fit: metrics_centralized {'accuracy': [(0, 0.0065625), (1, 0.069375), (2, 0.079375), (3, 0.074375), (4, 0.074375), (5, 0.19125), (6, 0.2271875), (7, 0.26625), (8, 0.346875), (9, 0.3846875), (10, 0.3671875)]}

# %%
log(
    INFO,
    "Size of the list with the model parameters: %s",
    len(parameters_for_each_round),
)
# Out:
# INFO flwr 2025-02-09 22:33:18,539 | <ipython-input-86-bcae8adbe4a8>:1 | Size of the list with the model parameters: 11
# INFO:flwr:Size of the list with the model parameters: 11

# %% [markdown]
# ---
#
# **Question 9 (Part II ✅ | Part III/MPhil ✅):**
#
# (You must provide the answer with **code** and **plots** for this question. A short written argumentation is recommended.)
#
# Now that an entire FL experiment can be trained, it is worth considering the relationship between the FL model across rounds. If we consider the final model $\theta^N$ obtained after $N$ rounds to be the optimal model $\theta^*$, we can ask how optimization step contributed to reaching $\theta^*$.
#
# 1. Run an FL simulation for at-least 50 rounds.

# %%
parameters_per_round, hist = run_simulation(
    num_rounds=50,
)
# Out:
# INFO flwr 2025-02-09 22:33:18,546 | <ipython-input-84-ce7914585fee>:56 | FL will execute for 50 rounds
# INFO:flwr:FL will execute for 50 rounds
# INFO flwr 2025-02-09 22:33:18,550 | app.py:149 | Starting Flower simulation, config: ServerConfig(num_rounds=50, round_timeout=None)
# INFO:flwr:Starting Flower simulation, config: ServerConfig(num_rounds=50, round_timeout=None)
# INFO flwr 2025-02-09 22:33:18,552 | server_returns_parameters.py:81 | Initializing global parameters
# INFO:flwr:Initializing global parameters
# INFO flwr 2025-02-09 22:33:18,554 | server_returns_parameters.py:273 | Using initial parameters provided by strategy
# INFO:flwr:Using initial parameters provided by strategy
# INFO flwr 2025-02-09 22:33:18,559 | server_returns_parameters.py:84 | Evaluating initial parameters
# INFO:flwr:Evaluating initial parameters
# /content/common/femnist_dataset.py:98: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(preprocessed_path)
#  11%|█         | 100/891 [00:00<00:07, 107.81it/s]
# INFO flwr 2025-02-09 22:33:19,514 | server_returns_parameters.py:87 | initial parameters (loss, other metrics): 413.6843070983887, {'accuracy': 0.0065625}
# INFO:flwr:initial parameters (loss, other metrics): 413.6843070983887, {'accuracy': 0.0065625}
# INFO flwr 2025-02-09 22:33:19,515 | server_returns_parameters.py:97 | FL starting
# INFO:flwr:FL starting
# DEBUG flwr 2025-02-09 22:33:19,518 | server_returns_parameters.py:223 | fit_round 1: strategy sampled 5 clients (out of 20)
# DEBUG:flwr:fit_round 1: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-09 22:33:19,520 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1494
# INFO:flwr:cid: 1494
# INFO flwr 2025-02-09 22:33:19,520 | <ipython-input-60-2c3670f7beb9>:21 | cid: 3119
# INFO flwr 2025-02-09 22:33:19,521 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2600
# INFO flwr 2025-02-09 22:33:19,524 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2399
# INFO flwr 2025-02-09 22:33:19,525 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1571
# INFO:flwr:cid: 3119
# INFO:flwr:cid: 2600
# INFO:flwr:cid: 2399
# INFO:flwr:cid: 1571
# DEBUG flwr 2025-02-09 22:33:21,101 | server_returns_parameters.py:237 | fit_round 1 received 5 results and 0 failures
# DEBUG:flwr:fit_round 1 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 109.76it/s]
# INFO flwr 2025-02-09 22:33:22,042 | server_returns_parameters.py:120 | fit progress: (1, 359.2395510673523, {'accuracy': 0.074375}, 2.523745270999825)
# INFO:flwr:fit progress: (1, 359.2395510673523, {'accuracy': 0.074375}, 2.523745270999825)
# INFO flwr 2025-02-09 22:33:22,043 | server_returns_parameters.py:171 | evaluate_round 1: no clients selected, cancel
# INFO:flwr:evaluate_round 1: no clients selected, cancel
# DEBUG flwr 2025-02-09 22:33:22,045 | server_returns_parameters.py:223 | fit_round 2: strategy sampled 5 clients (out of 20)
# DEBUG:flwr:fit_round 2: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-09 22:33:22,049 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1473
# INFO:flwr:cid: 1473
# INFO flwr 2025-02-09 22:33:22,050 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2600
# INFO:flwr:cid: 2600
# INFO flwr 2025-02-09 22:33:22,053 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1363
# INFO flwr 2025-02-09 22:33:22,055 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1494
# INFO:flwr:cid: 1363
# INFO flwr 2025-02-09 22:33:22,056 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2997
# INFO:flwr:cid: 1494
# INFO:flwr:cid: 2997
# DEBUG flwr 2025-02-09 22:33:23,730 | server_returns_parameters.py:237 | fit_round 2 received 5 results and 0 failures
# DEBUG:flwr:fit_round 2 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 108.25it/s]
# INFO flwr 2025-02-09 22:33:24,685 | server_returns_parameters.py:120 | fit progress: (2, 341.60364842414856, {'accuracy': 0.074375}, 5.166649679000329)
# INFO:flwr:fit progress: (2, 341.60364842414856, {'accuracy': 0.074375}, 5.166649679000329)
# INFO flwr 2025-02-09 22:33:24,687 | server_returns_parameters.py:171 | evaluate_round 2: no clients selected, cancel
# INFO:flwr:evaluate_round 2: no clients selected, cancel
# DEBUG flwr 2025-02-09 22:33:24,689 | server_returns_parameters.py:223 | fit_round 3: strategy sampled 5 clients (out of 20)
# DEBUG:flwr:fit_round 3: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-09 22:33:24,692 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2600
# INFO:flwr:cid: 2600
# INFO flwr 2025-02-09 22:33:24,695 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1498
# INFO:flwr:cid: 1498
# INFO flwr 2025-02-09 22:33:24,698 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1260
# INFO:flwr:cid: 1260
# INFO flwr 2025-02-09 22:33:24,707 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1473
# INFO:flwr:cid: 1473
# INFO flwr 2025-02-09 22:33:24,709 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2907
# INFO:flwr:cid: 2907
# DEBUG flwr 2025-02-09 22:33:26,569 | server_returns_parameters.py:237 | fit_round 3 received 5 results and 0 failures
# DEBUG:flwr:fit_round 3 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 110.31it/s]
# INFO flwr 2025-02-09 22:33:27,506 | server_returns_parameters.py:120 | fit progress: (3, 343.46106457710266, {'accuracy': 0.060625}, 7.987809616999584)
# INFO:flwr:fit progress: (3, 343.46106457710266, {'accuracy': 0.060625}, 7.987809616999584)
# INFO flwr 2025-02-09 22:33:27,508 | server_returns_parameters.py:171 | evaluate_round 3: no clients selected, cancel
# INFO:flwr:evaluate_round 3: no clients selected, cancel
# DEBUG flwr 2025-02-09 22:33:27,510 | server_returns_parameters.py:223 | fit_round 4: strategy sampled 5 clients (out of 20)
# DEBUG:flwr:fit_round 4: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-09 22:33:27,513 | <ipython-input-60-2c3670f7beb9>:21 | cid: 839
# INFO:flwr:cid: 839
# INFO flwr 2025-02-09 22:33:27,515 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2600
# INFO:flwr:cid: 2600
# INFO flwr 2025-02-09 22:33:27,518 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1473
# INFO:flwr:cid: 1473
# INFO flwr 2025-02-09 22:33:27,519 | <ipython-input-60-2c3670f7beb9>:21 | cid: 3119
# INFO:flwr:cid: 3119
# INFO flwr 2025-02-09 22:33:27,528 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1363
# INFO:flwr:cid: 1363
# DEBUG flwr 2025-02-09 22:33:29,077 | server_returns_parameters.py:237 | fit_round 4 received 5 results and 0 failures
# DEBUG:flwr:fit_round 4 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 110.83it/s]
# INFO flwr 2025-02-09 22:33:30,011 | server_returns_parameters.py:120 | fit progress: (4, 322.7896990776062, {'accuracy': 0.1490625}, 10.492948367000281)
# INFO:flwr:fit progress: (4, 322.7896990776062, {'accuracy': 0.1490625}, 10.492948367000281)
# INFO flwr 2025-02-09 22:33:30,013 | server_returns_parameters.py:171 | evaluate_round 4: no clients selected, cancel
# INFO:flwr:evaluate_round 4: no clients selected, cancel
# DEBUG flwr 2025-02-09 22:33:30,014 | server_returns_parameters.py:223 | fit_round 5: strategy sampled 5 clients (out of 20)
# DEBUG:flwr:fit_round 5: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-09 22:33:30,018 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2530
# INFO:flwr:cid: 2530
# INFO flwr 2025-02-09 22:33:30,019 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2600
# INFO:flwr:cid: 2600
# INFO flwr 2025-02-09 22:33:30,020 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1498
# INFO flwr 2025-02-09 22:33:30,023 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1603
# INFO:flwr:cid: 1498
# INFO:flwr:cid: 1603
# INFO flwr 2025-02-09 22:33:30,024 | <ipython-input-60-2c3670f7beb9>:21 | cid: 678
# INFO:flwr:cid: 678
# DEBUG flwr 2025-02-09 22:33:31,811 | server_returns_parameters.py:237 | fit_round 5 received 5 results and 0 failures
# DEBUG:flwr:fit_round 5 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 109.83it/s]
# INFO flwr 2025-02-09 22:33:32,752 | server_returns_parameters.py:120 | fit progress: (5, 306.6164038181305, {'accuracy': 0.2046875}, 13.23375465800018)
# INFO:flwr:fit progress: (5, 306.6164038181305, {'accuracy': 0.2046875}, 13.23375465800018)
# INFO flwr 2025-02-09 22:33:32,753 | server_returns_parameters.py:171 | evaluate_round 5: no clients selected, cancel
# INFO:flwr:evaluate_round 5: no clients selected, cancel
# DEBUG flwr 2025-02-09 22:33:32,756 | server_returns_parameters.py:223 | fit_round 6: strategy sampled 5 clients (out of 20)
# DEBUG:flwr:fit_round
| <ipython-input-60-2c3670f7beb9>:21 | cid: 2530
# INFO flwr 2025-02-09 22:33:37,840 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2997
# INFO:flwr:cid: 2530
# INFO flwr 2025-02-09 22:33:37,841 | <ipython-input-60-2c3670f7beb9>:21 | cid: 839
# INFO:flwr:cid: 2997
# INFO:flwr:cid: 839
# DEBUG flwr 2025-02-09 22:33:39,874 | server_returns_parameters.py:237 | fit_round 8 received 5 results and 0 failures
# DEBUG:flwr:fit_round 8 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:06, 114.03it/s]
# INFO flwr 2025-02-09 22:33:40,782 | server_returns_parameters.py:120 | fit progress: (8, 222.21865326166153, {'accuracy': 0.48}, 21.26406816799954)
# INFO:flwr:fit progress: (8, 222.21865326166153, {'accuracy': 0.48}, 21.26406816799954)
# INFO flwr 2025-02-09 22:33:40,784 | server_returns_parameters.py:171 | evaluate_round 8: no clients selected, cancel
# INFO:flwr:evaluate_round 8: no clients selected, cancel
# DEBUG flwr 2025-02-09 22:33:40,786 | server_returns_parameters.py:223 | fit_round 9: strategy sampled 5 clients (out of 20)
# DEBUG:flwr:fit_round 9: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-09 22:33:40,790 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1498
# INFO:flwr:cid: 1498
# INFO flwr 2025-02-09 22:33:40,790 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1363
# INFO:flwr:cid: 1363
# INFO flwr 2025-02-09 22:33:40,791 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2997
# INFO:flwr:cid: 2997
# INFO flwr 2025-02-09 22:33:40,794 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1603
# INFO:flwr:cid: 1603
# INFO flwr 2025-02-09 22:33:40,797 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1571
# INFO:flwr:cid: 1571
# DEBUG flwr 2025-02-09 22:33:42,402 | server_returns_parameters.py:237 | fit_round 9 received 5 results and 0 failures
# DEBUG:flwr:fit_round 9 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 110.47it/s]
# INFO flwr 2025-02-09 22:33:43,338 | server_returns_parameters.py:120 | fit progress: (9, 220.68986064195633, {'accuracy': 0.5025}, 23.81955461799953)
# INFO:flwr:fit progress: (9, 220.68986064195633, {'accuracy': 0.5025}, 23.81955461799953)
# INFO flwr 2025-02-09 22:33:43,339 | server_returns_parameters.py:171 | evaluate_round 9: no clients selected, cancel
# INFO:flwr:evaluate_round 9: no clients selected, cancel
# DEBUG flwr 2025-02-09 22:33:43,341 | server_returns_parameters.py:223 | fit_round 10: strategy sampled 5 clients (out of 20)
# DEBUG:flwr:fit_round 10: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-09 22:33:43,343 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2530
# INFO:flwr:cid: 2530
# INFO flwr 2025-02-09 22:33:43,344 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1571
# INFO:flwr:cid: 1571
# INFO flwr 2025-02-09 22:33:43,346 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1260
# INFO:flwr:cid: 1260
# INFO flwr 2025-02-09 22:33:43,351 | <ipython-input-60-2c3670f7beb9>:21 | cid: 678
# INFO:flwr:cid: 678
# INFO flwr 2025-02-09 22:33:43,353 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2184
# INFO:flwr:cid: 2184
# DEBUG flwr 2025-02-09 22:33:45,287 | server_returns_parameters.py:237 | fit_round 10 received 5 results and 0 failures
# DEBUG:flwr:fit_round 10 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 109.31it/s]
# INFO flwr 2025-02-09 22:33:46,232 | server_returns_parameters.py:120 | fit progress: (10, 218.61377894878387, {'accuracy': 0.46875}, 26.713703710999653)
# INFO:flwr:fit progress: (10, 218.61377894878387, {'accuracy': 0.46875}, 26.713703710999653)
# INFO flwr 2025-02-09 22:33:46,233 | server_returns_parameters.py:171 | evaluate_round 10: no clients selected, cancel
# INFO:flwr:evaluate_round 10: no clients selected, cancel
# DEBUG flwr 2025-02-09 22:33:46,236 | server_returns_parameters.py:223 | fit_round 11: strategy sampled 5 clients (out of 20)
# DEBUG:flwr:fit_round 11: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-09 22:33:46,239 | <ipython-input-60-2c3670f7beb9>:21 | cid: 3119
# INFO:flwr:cid: 3119
# INFO flwr 2025-02-09 22:33:46,240 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1363
# INFO:flwr:cid: 1363
# INFO flwr 2025-02-09 22:33:46,246 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2997
# INFO:flwr:cid: 2997
# INFO flwr 2025-02-09 22:33:46,248 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2399
# INFO:flwr:cid: 2399
# INFO flwr 2025-02-09 22:33:46,251 | <ipython-input-60-2c3670f7beb9>:21 | cid: 839
# INFO:flwr:cid: 839
# DEBUG flwr 2025-02-09 22:33:47,915 | server_returns_parameters.py:237 | fit_round 11 received 5 results and 0 failures
# DEBUG:flwr:fit_round 11 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 108.93it/s]
# INFO flwr 2025-02-09 22:33:48,863 | server_returns_parameters.py:120 | fit progress: (11, 200.3866822719574, {'accuracy': 0.5321875}, 29.34534048200021)
# INFO:flwr:fit progress: (11, 200.3866822719574, {'accuracy': 0.5321875}, 29.34534048200021)
# INFO flwr 2025-02-09 22:33:48,866 | server_returns_parameters.py:171 | evaluate_round 11: no clients selected, cancel
# INFO:flwr:evaluate_round 11: no clients selected, cancel
# DEBUG flwr 2025-02-09 22:33:48,868 | server_returns_parameters.py:223 | fit_round 12: strategy sampled 5 clients (out of 20)
# DEBUG:flwr:fit_round 12: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-09 22:33:48,871 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2184
# INFO:flwr:cid: 2184
# INFO flwr 2025-02-09 22:33:48,872 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2855
# INFO:flwr:cid: 2855
# INFO flwr 2025-02-09 22:33:48,873 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1603
# INFO flwr 2025-02-09 22:33:48,876 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2530
# INFO:flwr:cid: 1603
# INFO:flwr:cid: 2530
# INFO flwr 2025-02-09 22:33:48,877 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2688
# INFO:flwr:cid: 2688
# DEBUG flwr 2025-02-09 22:33:50,446 | server_returns_parameters.py:237 | fit_round 12 received 5 results and 0 failures
# DEBUG:flwr:fit_round 12 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 110.15it/s]
# INFO flwr 2025-02-09 22:33:51,385 | server_returns_parameters.py:120 | fit progress: (12, 190.6040621995926, {'accuracy': 0.540625}, 31.866888610000387)
# INFO:flwr:fit progress: (12, 190.6040621995926, {'accuracy': 0.540625}, 31.866888610000387)
# INFO flwr 2025-02-09 22:33:51,387 | server_returns_parameters.py:171 | evaluate_round 12: no clients selected, cancel
# INFO:flwr:evaluate_round 12: no clients selected, cancel
# DEBUG flwr 2025-02-09 22:33:51,388 | server_returns_parameters.py:223 | fit_round 13: strategy sampled 5 clients (out of 20)
# DEBUG:flwr:fit_round 13: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-09 22:33:51,393 | <ipython-input-60-2c3670f7beb9>:21 | cid: 3119
# INFO:flwr:cid: 3119
# INFO flwr 2025-02-09 22:33:51,394 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2600
# INFO flwr 2025-02-09 22:33:51,394 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1494
# INFO:flwr:cid: 2600
# INFO:flwr:cid: 1494
# INFO flwr 2025-02-09 22:33:51,397 | <ipython-input-60-2c3670f7beb9>:21 | cid: 3175
# INFO flwr 2025-02-09 22:33:51,398 | <ipython-input-60-2c3670f7beb9>:21 | cid: 839
# INFO:flwr:cid: 3175
# INFO:flwr:cid: 839
# DEBUG flwr 2025-02-09 22:33:53,079 | server_returns_parameters.py:237 | fit_round 13 received 5 results and 0 failures
# DEBUG:flwr:fit_round 13 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 100.40it/s]
# INFO flwr 2025-02-09 22:33:54,105 | server_returns_parameters.py:120 | fit progress: (13, 180.76564520597458, {'accuracy': 0.5565625}, 34.586558760000116)
# INFO:flwr:fit progress: (13, 180.76564520597458, {'accuracy': 0.5565625}, 34.586558760000116)
# INFO flwr 2025-02-09 22:33:54,106 | server_returns_parameters.py:171 | evaluate_round 13: no clients selected, cancel
# INFO:flwr:evaluate_round 13: no clients selected, cancel
# DEBUG flwr 2025-02-09 22:33:54,108 | server_returns_parameters.py:223 | fit_round 14: strategy sampled 5 clients (out of 20)
# DEBUG:flwr:fit_round 14: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-09 22:33:54,113 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2907
# INFO:flwr:cid: 2907
# INFO flwr 2025-02-09 22:33:54,114 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2338
# INFO flwr 2025-02-09 22:33:54,115 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2184
# INFO:flwr:cid: 2338
# INFO:flwr:cid: 2184
# INFO flwr 2025-02-09 22:33:54,116 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2399
# INFO flwr 2025-02-09 22:33:54,120 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1571
# INFO:flwr:cid: 2399
# INFO:flwr:cid: 1571
# DEBUG flwr 2025-02-09 22:33:55,841 | server_returns_parameters.py:237 | fit_round 14 received 5 results and 0 failures
# DEBUG:flwr:fit_round 14 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 102.96it/s]
# INFO flwr 2025-02-09 22:33:56,843 | server_returns_parameters.py:120 | fit progress: (14, 180.030358761549, {'accuracy': 0.595625}, 37.32509451199985)
# INFO:flwr:fit progress: (14, 180.030358761549, {'accuracy': 0.595625}, 37.32509451199985)
# INFO flwr 2025-02-09 22:33:56,845 | server_returns_parameters.py:171 | evaluate_round 14: no clients selected, cancel
# INFO:flwr:evaluate_round 14: no clients selected, cancel
# DEBUG flwr 2025-02-09 22:33:56,847 | server_returns_parameters.py:223 | fit_round 15: strategy sampled 5 clients (out of 20)
# DEBUG:flwr:fit_round 15: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-09 22:33:56,851 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2907
# INFO:flwr:cid: 2907
# INFO flwr 2025-02-09 22:33:56,851 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2997
# INFO flwr 2025-02-09 22:33:56,852 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1603
# INFO:flwr:cid: 2997
# INFO flwr 2025-02-09 22:33:56,857 | <ipython-input-60-2c3670f7beb9>:21 | cid: 3175
# INFO:flwr:cid: 1603
# INFO flwr 2025-02-09 22:33:56,862 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2184
# INFO:flwr:cid: 3175
# INFO:flwr:cid: 2184
# DEBUG flwr 2025-02-09 22:33:58,568 | server_returns_parameters.py:237 | fit_round 15 received 5 results and 0 failures
# DEBUG:flwr:fit_round 15 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 102.41it/s]
# INFO flwr 2025-02-09 22:33:59,576 | server_returns_parameters.py:120 | fit progress: (15, 181.10523527860641, {'accuracy': 0.5834375}, 40.05801167000027)
# INFO:flwr:fit progress: (15, 181.10523527860641, {'accuracy': 0.5834375}, 40.05801167000027)
# INFO flwr 2025-02-09 22:33:59,579 | server_returns_parameters.py:171 | evaluate_round 15: no clients selected, cancel
# INFO:flwr:evaluate_round 15: no clients selected, cancel
# DEBUG flwr 2025-02-09 22:33:59,583 | server_returns_parameters.py:223 | fit_round 16: strategy sampled 5 clients (out of 20)
# DEBUG:flwr:fit_round 16: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-09 22:33:59,587 | <ipython-input-60-2c3670f7beb9>:21 | cid: 3119
# INFO:flwr:cid: 3119
# INFO flwr 2025-02-09 22:33:59,587 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2338
# INFO:flwr:cid: 2338
# INFO flwr 2025-02-09 22:33:59,587 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1260
# INFO:flwr:cid: 1260
# INFO flwr 2025-02-09 22:33:59,589 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2600
# INFO:flwr:cid: 2600
# INFO flwr 2025-02-09 22:33:59,591 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2184
# INFO:flwr:cid: 2184
# DEBUG flwr 2025-02-09 22:34:01,716 | server_returns_parameters.py:237 | fit_round 16 received 5 results and 0 failures
# DEBUG:flwr:fit_round 16 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 106.82it/s]
# INFO flwr 2025-02-09 22:34:02,684 | server_returns_parameters.py:120 | fit progress: (16, 164.69252854585648, {'accuracy': 0.5884375}, 43.16588449699975)
# INFO:flwr:fit progress: (16, 164.69252854585648, {'accuracy': 0.5884375}, 43.16588449699975)
# INFO flwr 2025-02-09 22:34:02,686 | server_returns_parameters.py:171 | evaluate_round 16: no clients selected, cancel
# INFO:flwr:evaluate_round 16: no clients selected, cancel
# DEBUG flwr 2025-02-09 22:34:02,688 | server_returns_parameters.py:223 | fit_round 17: strategy sampled 5 clients (out of 20)
# DEBUG:flwr:fit_round 17: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-09 22:34:02,692 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1260
# INFO:flwr:cid: 1260
# INFO flwr 2025-02-09 22:34:02,693 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1363
# INFO:flwr:cid: 1363
# INFO flwr 2025-02-09 22:34:02,694 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2338
# INFO:flwr:cid: 2338
# INFO flwr 2025-02-09 22:34:02,699 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2184
# INFO flwr 2025-02-09 22:34:02,699 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1603
# INFO:flwr:cid: 2184
# INFO:flwr:cid: 1603
# DEBUG flwr 2025-02-09 22:34:04,539 | server_returns_parameters.py:237 | fit_round 17 received 5 results and 0 failures
# DEBUG:flwr:fit_round 17 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 105.38it/s]
# INFO flwr 2025-02-09 22:34:05,517 | server_returns_parameters.py:120 | fit progress: (17, 163.16318780183792, {'accuracy': 0.60125}, 45.99934615100028)
# INFO:flwr:fit progress: (17, 163.16318780183792, {'accuracy': 0.60125}, 45.99934615100028)
# INFO flwr 2025-02-09 22:34:05,521 | server_returns_parameters.py:171 | evaluate_round 17: no clients selected, cancel
# INFO:flwr:evaluate_round 17: no clients selected, cancel
# DEBUG flwr 2025-02-09 22:34:05,525 | server_returns_parameters.py:223 | fit_round 18: strategy sampled 5 clients (out of 20)
# DEBUG:flwr:fit_round 18: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-09 22:34:05,527 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2600
# INFO:flwr:cid: 2600
# INFO flwr 2025-02-09 22:34:05,528 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1473
# INFO:flwr:cid: 1473
# INFO flwr 2025-02-09 22:34:05,529 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2907
# INFO:flwr:cid: 2907
# INFO flwr 2025-02-09 22:34:05,532 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2997
# INFO flwr 2025-02-09 22:34:05,539 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1494
# INFO:flwr:cid: 2997
# INFO:flwr:cid: 1494
# DEBUG flwr 2025-02-09 22:34:07,212 | server_returns_parameters.py:237 | fit_round 18 received 5 results and 0 failures
# DEBUG:flwr:fit_round 18 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 109.06it/s]
# INFO flwr 2025-02-09 22:34:08,163 | server_returns_parameters.py:120 | fit progress: (18, 162.30741566419601, {'accuracy': 0.6071875}, 48.644852088000334)
# INFO:flwr:fit progress: (18, 162.30741566419601, {'accuracy': 0.6071875}, 48.644852088000334)
# INFO flwr 2025-02-09 22:34:08,165 | server_returns_parameters.py:171 | evaluate_round 18: no clients selected, cancel
# INFO:flwr:evaluate_round 18: no clients selected, cancel
# DEBUG flwr 2025-02-09 22:34:08,167 | server_returns_parameters.py:223 | fit_round 19: strategy sampled 5 clients (out of 20)
# DEBUG:flwr:fit_round 19: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-09 22:34:08,169 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1494
# INFO:flwr:cid: 1494
# INFO flwr 2025-02-09 22:34:08,175 | <ipython-input-60-2c3670f7beb9>:21 | cid: 3175
# INFO flwr 2025-02-09 22:34:08,175 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2997
# INFO:flwr:cid: 3175
# INFO:flwr:cid: 2997
# INFO flwr 2025-02-09 22:34:08,177 | <ipython-input-60-2c3670f7beb9>:21 | cid: 3119
# INFO:flwr:cid: 3119
# INFO flwr 2025-02-09 22:34:08,181 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2338
# INFO:flwr:cid: 2338
# DEBUG flwr 2025-02-09 22:34:10,015 | server_returns_parameters.py:237 | fit_round 19 received 5 results and 0 failures
# DEBUG:flwr:fit_round 19 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 107.87it/s]
# INFO flwr 2025-02-09 22:34:10,974 | server_returns_parameters.py:120 | fit progress: (19, 158.71247684955597, {'accuracy': 0.59625}, 51.45571638199999)
# INFO:flwr:fit progress: (19, 158.71247684955597, {'accuracy': 0.59625}, 51.45571638199999)
# INFO flwr 2025-02-09 22:34:10,976 | server_returns_parameters.py:171 | evaluate_round 19: no clients selected, cancel
# INFO:flwr:evaluate_round 19: no clients selected, cancel
# DEBUG flwr 2025-02-09 22:34:10,978 | server_returns_parameters.py:223 | fit_round 20: strategy sampled 5 clients (out of 20)
# DEBUG:flwr:fit_round 20: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-09 22:34:10,983 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2855
# INFO:flwr:cid: 2855
# INFO flwr 2025-02-09 22:34:10,985 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1473
# INFO:flwr:cid: 1473
# INFO flwr 2025-02-09 22:34:10,988 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1260
# INFO:flwr:cid: 1260
# INFO flwr 2025-02-09 22:34:10,993 | <ipython-input-60-2c3670f7beb9>:21 | cid: 3175
# INFO flwr 2025-02-09 22:34:10,994 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2399
# INFO:flwr:cid: 3175
# INFO:flwr:cid: 2399
# DEBUG flwr 2025-02-09 22:34:12,937 | server_returns_parameters.py:237 | fit_round 20 received 5 results and 0 failures
# DEBUG:flwr:fit_round 20 received 5 results and 0 failures
#  11%|█         | 100/891 [00:01<00:08, 96.46it/s]
# INFO flwr 2025-02-09 22:34:14,021 | server_returns_parameters.py:120 | fit progress: (20, 154.5262708067894, {'accuracy': 0.58125}, 54.50262506099989)
# INFO:flwr:fit progress: (20, 154.5262708067894, {'accuracy': 0.58125}, 54.50262506099989)
# INFO flwr 2025-02-09 22:34:14,022 | server_returns_parameters.py:171 | evaluate_round 20: no clients selected, cancel
# INFO:flwr:evaluate_round 20: no clients selected, cancel
# DEBUG flwr 2025-02-09 22:34:14,024 | server_returns_parameters.py:223 | fit_round 21: strategy sampled 5 clients (out of 20)
# DEBUG:flwr:fit_round 21: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-09 22:34:14,028 | <ipython-input-60-2c3670f7beb9>:21 | cid: 678
# INFO:flwr:cid: 678
# INFO flwr 2025-02-09 22:34:14,029 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1571
# INFO flwr 2025-02-09 22:34:14,032 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1473
# INFO:flwr:cid: 1571
# INFO flwr 2025-02-09 22:34:14,034 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2997
# INFO flwr 2025-02-09 22:34:14,035 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1260
# INFO:flwr:cid: 1473
# INFO:flwr:cid: 2997
# INFO:flwr:cid: 1260
# DEBUG flwr 2025-02-09 22:34:16,065 | server_returns_parameters.py:237 | fit_round 21 received 5 results and 0 failures
# DEBUG:flwr:fit_round 21 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 109.58it/s]
# INFO flwr 2025-02-09 22:34:17,008 | server_returns_parameters.py:120 | fit progress: (21, 184.78053736686707, {'accuracy': 0.5153125}, 57.48984578700038)
# INFO:flwr:fit progress: (21, 184.78053736686707, {'accuracy': 0.5153125}, 57.48984578700038)
# INFO flwr 2025-02-09 22:34:17,009 | server_returns_parameters.py:171 | evaluate_round 21: no clients selected, cancel
# INFO:flwr:evaluate_round 21: no clients selected, cancel
# DEBUG flwr 2025-02-09 22:34:17,012 | server_returns_parameters.py:223 | fit_round 22: strategy sampled 5 clients (out of 20)
# DEBUG:flwr:fit_round 22: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-09 22:34:17,016 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2399
# INFO:flwr:cid: 2399
# INFO flwr 2025-02-09 22:34:17,018 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2855
# INFO flwr 2025-02-09 22:34:17,020 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1571
# INFO flwr 2025-02-09 22:34:17,021 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2184
# INFO:flwr:cid: 2855
# INFO flwr 2025-02-09 22:34:17,025 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2530
# INFO:flwr:cid: 1571
# INFO:flwr:cid: 2184
# INFO:flwr:cid: 2530
# DEBUG flwr 2025-02-09 22:34:18,724 | server_returns_parameters.py:237 | fit_round 22 received 5 results and 0 failures
# DEBUG:flwr:fit_round 22 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 108.74it/s]
# INFO flwr 2025-02-09 22:34:19,673 | server_returns_parameters.py:120 | fit progress: (22, 144.44334936141968, {'accuracy': 0.6321875}, 60.15552109999953)
# INFO:flwr:fit progress: (22, 144.44334936141968, {'accuracy': 0.6321875}, 60.15552109999953)
# INFO flwr 2025-02-09 22:34:19,675 | server_returns_parameters.py:171 | evaluate_round 22: no clients selected, cancel
# INFO:flwr:evaluate_round 22: no clients selected, cancel
# DEBUG flwr 2025-02-09 22:34:19,678 | server_returns_parameters.py:223 | fit_round 23: strategy sampled 5 clients (out of 20)
# DEBUG:flwr:fit_round 23: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-09 22:34:19,681 | <ipython-input-60-2c3670f7beb9>:21 | cid: 3119
# INFO:flwr:cid: 3119
# INFO flwr 2025-02-09 22:34:19,682 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2997
# INFO:flwr:cid: 2997
# INFO flwr 2025-02-09 22:34:19,684 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1260
# INFO:flwr:cid: 1260
# INFO flwr 2025-02-09 22:34:19,686 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1363
# INFO:flwr:cid: 1363
# INFO flwr 2025-02-09 22:34:19,692 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1571
# INFO:flwr:cid: 1571
# DEBUG flwr 2025-02-09 22:34:21,594 | server_returns_parameters.py:237 | fit_round 23 received 5 results and 0 failures
# DEBUG:flwr:fit_round 23 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 110.66it/s]
# INFO flwr 2025-02-09 22:34:22,528 | server_returns_parameters.py:120 | fit progress: (23, 170.22003665566444, {'accuracy': 0.5625}, 63.01043142599974)
# INFO:flwr:fit progress: (23, 170.22003665566444, {'accuracy': 0.5625}, 63.01043142599974)
# INFO flwr 2025-02-09 22:34:22,530 | server_returns_parameters.py:171 | evaluate_round 23: no clients selected, cancel
# INFO:flwr:evaluate_round 23: no clients selected, cancel
# DEBUG flwr 2025-02-09 22:34:22,534 | server_returns_parameters.py:223 | fit_round 24: strategy sampled 5 clients (out of 20)
# DEBUG:flwr:fit_round 24: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-09 22:34:22,536 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1473
# INFO:flwr:cid: 1473
# INFO flwr 2025-02-09 22:34:22,537 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2600
# INFO:flwr:cid: 2600
# INFO flwr 2025-02-09 22:34:22,539 | <ipython-input-60-2c3670f7beb9>:21 | cid: 678
# INFO flwr 2025-02-09 22:34:22,541 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1363
# INFO:flwr:cid: 678
# INFO flwr 2025-02-09 22:34:22,545 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1603
# INFO:flwr:cid: 1363
# INFO:flwr:cid: 1603
# DEBUG flwr 2025-02-09 22:34:24,106 | server_returns_parameters.py:237 | fit_round 24 received 5 results and 0 failures
# DEBUG:flwr:fit_round 24 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 110.14it/s]
# INFO flwr 2025-02-09 22:34:25,045 | server_returns_parameters.py:120 | fit progress: (24, 139.5694078207016, {'accuracy': 0.61875}, 65.52703030799967)
# INFO:flwr:fit progress: (24, 139.5694078207016, {'accuracy': 0.61875}, 65.52703030799967)
# INFO flwr 2025-02-09 22:34:25,047 | server_returns_parameters.py:171 | evaluate_round 24: no clients selected, cancel
# INFO:flwr:evaluate_round 24: no clients selected, cancel
# DEBUG flwr 2025-02-09 22:34:25,050 | server_returns_parameters.py:223 | fit_round 25: strategy sampled 5 clients (out of 20)
# DEBUG:flwr:fit_round 25: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-09 22:34:25,053 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2688
# INFO:flwr:cid: 2688
# INFO flwr 2025-02-09 22:34:25,054 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1473
# INFO:flwr:cid: 1473
# INFO flwr 2025-02-09 22:34:25,055 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1494
# INFO:flwr:cid: 1494
# INFO flwr 2025-02-09 22:34:25,057 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2338
# INFO:flwr:cid: 2338
# INFO flwr 2025-02-09 22:34:25,061 | <ipython-input-60-2c3670f7beb9>:21 | cid: 3175
# INFO:flwr:cid: 3175
# DEBUG flwr 2025-02-09 22:34:26,648 | server_returns_parameters.py:237 | fit_round 25 received 5 results and 0 failures
# DEBUG:flwr:fit_round 25 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 112.50it/s]
# INFO flwr 2025-02-09 22:34:27,567 | server_returns_parameters.py:120 | fit progress: (25, 133.5232491493225, {'accuracy': 0.6615625}, 68.0491244470004)
# INFO:flwr:fit progress: (25, 133.5232491493225, {'accuracy': 0.6615625}, 68.0491244470004)
# INFO flwr 2025-02-09 22:34:27,569 | server_returns_parameters.py:171 | evaluate_round 25: no clients selected, cancel
# INFO:flwr:evaluate_round 25: no clients selected, cancel
# DEBUG flwr 2025-02-09 22:34:27,571 | server_returns_parameters.py:223 | fit_round 26: strategy sampled 5 clients (out of 20)
# DEBUG:flwr:fit_round 26: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-09 22:34:27,573 | <ipython-input-60-2c3670f7beb9>:21 | cid: 678
# INFO:flwr:cid: 678
# INFO flwr 2025-02-09 22:34:27,573 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1473
# INFO flwr 2025-02-09 22:34:27,575 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2907
# INFO flwr 2025-02-09 22:34:27,575 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1603
# INFO flwr 2025-02-09 22:34:27,579 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2530
# INFO:flwr:cid: 1473
# INFO:flwr:cid: 2907
# INFO:flwr:cid: 1603
# INFO:flwr:cid: 2530
# DEBUG flwr 2025-02-09 22:34:29,254 | server_returns_parameters.py:237 | fit_round 26 received 5 results and 0 failures
# DEBUG:flwr:fit_round 26 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 107.90it/s]
# INFO flwr 2025-02-09 22:34:30,212 | server_returns_parameters.py:120 | fit progress: (26, 146.3170984685421, {'accuracy': 0.596875}, 70.69430169499992)
# INFO:flwr:fit progress: (26, 146.3170984685421, {'accuracy': 0.596875}, 70.69430169499992)
# INFO flwr 2025-02-09 22:34:30,215 | server_returns_parameters.py:171 | evaluate_round 26: no clients selected, cancel
# INFO:flwr:evaluate_round 26: no clients selected, cancel
# DEBUG flwr 2025-02-09 22:34:30,217 | server_returns_parameters.py:223 | fit_round 27: strategy sampled 5 clients (out of 20)
# DEBUG:flwr:fit_round 27: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-09 22:34:30,219 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1571
# INFO:flwr:cid: 1571
# INFO flwr 2025-02-09 22:34:30,220 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2907
# INFO:flwr:cid: 2907
# INFO flwr 2025-02-09 22:34:30,223 | <ipython-input-60-2c3670f7beb9>:21 | cid: 3175
# INFO:flwr:cid: 3175
# INFO flwr 2025-02-09 22:34:30,224 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2855
# INFO flwr 2025-02-09 22:34:30,226 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1473
# INFO:flwr:cid: 2855
# INFO:flwr:cid: 1473
# DEBUG flwr 2025-02-09 22:34:31,827 | server_returns_parameters.py:237 | fit_round 27 received 5 results and 0 failures
# DEBUG:flwr:fit_round 27 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 112.19it/s]
# INFO flwr 2025-02-09 22:34:32,749 | server_returns_parameters.py:120 | fit progress: (27, 136.93521025776863, {'accuracy': 0.6825}, 73.23099015499974)
# INFO:flwr:fit progress: (27, 136.93521025776863, {'accuracy': 0.6825}, 73.23099015499974)
# INFO flwr 2025-02-09 22:34:32,751 | server_returns_parameters.py:171 | evaluate_round 27: no clients selected, cancel
# INFO:flwr:evaluate_round 27: no clients selected, cancel
# DEBUG flwr 2025-02-09 22:34:32,754 | server_returns_parameters.py:223 | fit_round 28: strategy sampled 5 clients (out of 20)
# DEBUG:flwr:fit_round 28: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-09 22:34:32,757 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2338
# INFO:flwr:cid: 2338
# INFO flwr 2025-02-09 22:34:32,758 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2184
# INFO:flwr:cid: 2184
# INFO flwr 2025-02-09 22:34:32,759 | <ipython-input-60-2c3670f7beb9>:21 | cid: 839
# INFO flwr 2025-02-09 22:34:32,762 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1473
# INFO:flwr:cid: 839
# INFO:flwr:cid: 1473
# INFO flwr 2025-02-09 22:34:32,765 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2997
# INFO:flwr:cid: 2997
# DEBUG flwr 2025-02-09 22:34:34,322 | server_returns_parameters.py:237 | fit_round 28 received 5 results and 0 failures
# DEBUG:flwr:fit_round 28 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 107.85it/s]
# INFO flwr 2025-02-09 22:34:35,281 | server_returns_parameters.py:120 | fit progress: (28, 141.44024923443794, {'accuracy': 0.6271875}, 75.76331497699994)
# INFO:flwr:fit progress: (28, 141.44024923443794, {'accuracy': 0.6271875}, 75.76331497699994)
# INFO flwr 2025-02-09 22:34:35,283 | server_returns_parameters.py:171 | evaluate_round 28: no clients selected, cancel
# INFO:flwr:evaluate_round 28: no clients selected, cancel
# DEBUG flwr 2025-02-09 22:34:35,285 | server_returns_parameters.py:223 | fit_round 29: strategy sampled 5 clients (out of 20)
# DEBUG:flwr:fit_round 29: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-09 22:34:35,290 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1603
# INFO:flwr:cid: 1603
# INFO flwr 2025-02-09 22:34:35,291 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1498
# INFO flwr 2025-02-09 22:34:35,296 | <ipython-input-60-2c3670f7beb9>:21 | cid: 678
# INFO:flwr:cid: 1498
# INFO:flwr:cid: 678
# INFO flwr 2025-02-09 22:34:35,298 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1363
# INFO:flwr:cid: 1363
# INFO flwr 2025-02-09 22:34:35,301 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2184
# INFO:flwr:cid: 2184
# DEBUG flwr 2025-02-09 22:34:36,935 | server_returns_parameters.py:237 | fit_round 29 received 5 results and 0 failures
# DEBUG:flwr:fit_round 29 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 110.57it/s]
# INFO flwr 2025-02-09 22:34:37,869 | server_returns_parameters.py:120 | fit progress: (29, 141.04994502663612, {'accuracy': 0.6484375}, 78.35114267300014)
# INFO:flwr:fit progress: (29, 141.04994502663612, {'accuracy': 0.6484375}, 78.35114267300014)
# INFO flwr 2025-02-09 22:34:37,871 | server_returns_parameters.py:171 | evaluate_round 29: no clients selected, cancel
# INFO:flwr:evaluate_round 29: no clients selected, cancel
# DEBUG flwr 2025-02-09 22:34:37,874 | server_returns_parameters.py:223 | fit_round 30: strategy sampled 5 clients (out of 20)
# DEBUG:flwr:fit_round 30: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-09 22:34:37,877 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2855
# INFO:flwr:cid: 2855
# INFO flwr 2025-02-09 22:34:37,878 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2997
# INFO:flwr:cid: 2997
# INFO flwr 2025-02-09 22:34:37,880 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2600
# INFO flwr 2025-02-09 22:34:37,881 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1571
# INFO flwr 2025-02-09 22:34:37,881 | <ipython-input-60-2c3670f7beb9>:21 | cid: 3175
# INFO:flwr:cid: 2600
# INFO:flwr:cid: 1571
# INFO:flwr:cid: 3175
# DEBUG flwr 2025-02-09 22:34:39,743 | server_returns_parameters.py:237 | fit_round 30 received 5 results and 0 failures
# DEBUG:flwr:fit_round 30 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 108.85it/s]
# INFO flwr 2025-02-09 22:34:40,692 | server_returns_parameters.py:120 | fit progress: (30, 153.8564929664135, {'accuracy': 0.6353125}, 81.17378406999978)
# INFO:flwr:fit progress: (30, 153.8564929664135, {'accuracy': 0.6353125}, 81.17378406999978)
# INFO flwr 2025-02-09 22:34:40,694 | server_returns_parameters.py:171 | evaluate_round 30: no clients selected, cancel
# INFO:flwr:evaluate_round 30: no clients selected, cancel
# DEBUG flwr 2025-02-09 22:34:40,697 | server_returns_parameters.py:223 | fit_round 31: strategy sampled 5 clients (out of 20)
# DEBUG:flwr:fit_round 31: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-09 22:34:40,701 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2688
# INFO:flwr:cid: 2688
# INFO flwr 2025-02-09 22:34:40,704 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1498
# INFO:flwr:cid: 1498
# INFO flwr 2025-02-09 22:34:40,705 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2338
# INFO:flwr:cid: 2338
# INFO flwr 2025-02-09 22:34:40,709 | <ipython-input-60-2c3670f7beb9>:21 | cid: 839
# INFO flwr 2025-02-09 22:34:40,712 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2184
# INFO:flwr:cid: 839
# INFO:flwr:cid: 2184
# DEBUG flwr 2025-02-09 22:34:42,315 | server_returns_parameters.py:237 | fit_round 31 received 5 results and 0 failures
# DEBUG:flwr:fit_round 31 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 112.62it/s]
# INFO flwr 2025-02-09 22:34:43,234 | server_returns_parameters.py:120 | fit progress: (31, 148.35161313414574, {'accuracy': 0.625}, 83.71580721899954)
# INFO:flwr:fit progress: (31, 148.35161313414574, {'accuracy': 0.625}, 83.71580721899954)
# INFO flwr 2025-02-09 22:34:43,235 | server_returns_parameters.py:171 | evaluate_round 31: no clients selected, cancel
# INFO:flwr:evaluate_round 31: no clients selected, cancel
# DEBUG flwr 2025-02-09 22:34:43,238 | server_returns_parameters.py:223 | fit_round 32: strategy sampled 5 clients (out of 20)
# DEBUG:flwr:fit_round 32: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-09 22:34:43,242 | <ipython-input-60-2c3670f7beb9>:21 | cid: 3119
# INFO:flwr:cid: 3119
# INFO flwr 2025-02-09 22:34:43,243 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2855
# INFO:flwr:cid: 2855
# INFO flwr 2025-02-09 22:34:43,244 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1363
# INFO:flwr:cid: 1363
# INFO flwr 2025-02-09 22:34:43,244 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2530
# INFO flwr 2025-02-09 22:34:43,248 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2338
# INFO:flwr:cid: 2530
# INFO:flwr:cid: 2338
# DEBUG flwr 2025-02-09 22:34:45,045 | server_returns_parameters.py:237 | fit_round 32 received 5 results and 0 failures
# DEBUG:flwr:fit_round 32 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 106.66it/s]
# INFO flwr 2025-02-09 22:34:46,014 | server_returns_parameters.py:120 | fit progress: (32, 138.91250467300415, {'accuracy': 0.6584375}, 86.49564676200043)
# INFO:flwr:fit progress: (32, 138.91250467300415, {'accuracy': 0.6584375}, 86.49564676200043)
# INFO flwr 2025-02-09 22:34:46,015 | server_returns_parameters.py:171 | evaluate_round 32: no clients selected, cancel
# INFO:flwr:evaluate_round 32: no clients selected, cancel
# DEBUG flwr 2025-02-09 22:34:46,017 | server_returns_parameters.py:223 | fit_round 33: strategy sampled 5 clients (out of 20)
# DEBUG:flwr:fit_round 33: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-09 22:34:46,021 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2338
# INFO:flwr:cid: 2338
# INFO flwr 2025-02-09 22:34:46,022 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1603
# INFO flwr 2025-02-09 22:34:46,024 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2907
# INFO:flwr:cid: 1603
# INFO flwr 2025-02-09 22:34:46,025 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2855
# INFO:flwr:cid: 2907
# INFO flwr 2025-02-09 22:34:46,028 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2688
# INFO:flwr:cid: 2855
# INFO:flwr:cid: 2688
# DEBUG flwr 2025-02-09 22:34:47,572 | server_returns_parameters.py:237 | fit_round 33 received 5 results and 0 failures
# DEBUG:flwr:fit_round 33 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 109.34it/s]
# INFO flwr 2025-02-09 22:34:48,519 | server_returns_parameters.py:120 | fit progress: (33, 141.61475956439972, {'accuracy': 0.6671875}, 89.00143201399987)
# INFO:flwr:fit progress: (33, 141.61475956439972, {'accuracy': 0.6671875}, 89.00143201399987)
# INFO flwr 2025-02-09 22:34:48,521 | server_returns_parameters.py:171 | evaluate_round 33: no clients selected, cancel
# INFO:flwr:evaluate_round 33: no clients selected, cancel
# DEBUG flwr 2025-02-09 22:34:48,523 | server_returns_parameters.py:223 | fit_round 34: strategy sampled 5 clients (out of 20)
# DEBUG:flwr:fit_round 34: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-09 22:34:48,527 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2530
# INFO:flwr:cid: 2530
# INFO flwr 2025-02-09 22:34:48,528 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2399
# INFO flwr 2025-02-09 22:34:48,529 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2997
# INFO:flwr:cid: 2399
# INFO flwr 2025-02-09 22:34:48,532 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2688
# INFO:flwr:cid: 2997
# INFO:flwr:cid: 2688
# INFO flwr 2025-02-09 22:34:48,533 | <ipython-input-60-2c3670f7beb9>:21 | cid: 678
# INFO:flwr:cid: 678
# DEBUG flwr 2025-02-09 22:34:50,457 | server_returns_parameters.py:237 | fit_round 34 received 5 results and 0 failures
# DEBUG:flwr:fit_round 34 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 109.13it/s]
# INFO flwr 2025-02-09 22:34:51,405 | server_returns_parameters.py:120 | fit progress: (34, 151.28600105643272, {'accuracy': 0.5946875}, 91.88669148400004)
# INFO:flwr:fit progress: (34, 151.28600105643272, {'accuracy': 0.5946875}, 91.88669148400004)
# INFO flwr 2025-02-09 22:34:51,406 | server_returns_parameters.py:171 | evaluate_round 34: no clients selected, cancel
# ...
# INFO:flwr:fit progress: (48, 141.2099066078663, {'accuracy': 0.6703125}, 129.63744792200032)
# INFO flwr 2025-02-09 22:35:29,157 | server_returns_parameters.py:171 | evaluate_round 48: no clients selected, cancel
# INFO:flwr:evaluate_round 48: no clients selected, cancel
# DEBUG flwr 2025-02-09 22:35:29,160 | server_returns_parameters.py:223 | fit_round 49: strategy sampled 5 clients (out of 20)
# DEBUG:flwr:fit_round 49: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-09 22:35:29,162 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2997
# INFO:flwr:cid: 2997
# INFO flwr 2025-02-09 22:35:29,162 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2907
# INFO flwr 2025-02-09 22:35:29,164 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1260
# INFO:flwr:cid: 2907
# INFO:flwr:cid: 1260
# INFO flwr 2025-02-09 22:35:29,168 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1494
# INFO flwr 2025-02-09 22:35:29,168 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2688
# INFO:flwr:cid: 1494
# INFO:flwr:cid: 2688
# DEBUG flwr 2025-02-09 22:35:31,102 | server_returns_parameters.py:237 | fit_round 49 received 5 results and 0 failures
# DEBUG:flwr:fit_round 49 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 107.24it/s]
# INFO flwr 2025-02-09 22:35:32,065 | server_returns_parameters.py:120 | fit progress: (49, 165.46274450421333, {'accuracy': 0.64625}, 132.5472466250003)
# INFO:flwr:fit progress: (49, 165.46274450421333, {'accuracy': 0.64625}, 132.5472466250003)
# INFO flwr 2025-02-09 22:35:32,067 | server_returns_parameters.py:171 | evaluate_round 49: no clients selected, cancel
# INFO:flwr:evaluate_round 49: no clients selected, cancel
# DEBUG flwr 2025-02-09 22:35:32,069 | server_returns_parameters.py:223 | fit_round 50: strategy sampled 5 clients (out of 20)
# DEBUG:flwr:fit_round 50: strategy sampled 5 clients (out of 20)
# INFO flwr 2025-02-09 22:35:32,074 | <ipython-input-60-2c3670f7beb9>:21 | cid: 3119
# INFO:flwr:cid: 3119
# INFO flwr 2025-02-09 22:35:32,075 | <ipython-input-60-2c3670f7beb9>:21 | cid: 839
# INFO:flwr:cid: 839
# INFO flwr 2025-02-09 22:35:32,078 | <ipython-input-60-2c3670f7beb9>:21 | cid: 2399
# INFO flwr 2025-02-09 22:35:32,081 | <ipython-input-60-2c3670f7beb9>:21 | cid: 1260
# INFO flwr 2025-02-09 22:35:32,082 | <ipython-input-60-2c3670f7beb9>:21 | cid: 678
# INFO:flwr:cid: 2399
# INFO:flwr:cid: 1260
# INFO:flwr:cid: 678
# DEBUG flwr 2025-02-09 22:35:34,078 | server_returns_parameters.py:237 | fit_round 50 received 5 results and 0 failures
# DEBUG:flwr:fit_round 50 received 5 results and 0 failures
#  11%|█         | 100/891 [00:00<00:07, 109.91it/s]
# INFO flwr 2025-02-09 22:35:35,020 | server_returns_parameters.py:120 | fit progress: (50, 163.70363584160805, {'accuracy': 0.5859375}, 135.50196442299966)
# INFO:flwr:fit progress: (50, 163.70363584160805, {'accuracy': 0.5859375}, 135.50196442299966)
# INFO flwr 2025-02-09 22:35:35,022 | server_returns_parameters.py:171 | evaluate_round 50: no clients selected, cancel
# INFO:flwr:app_fit: metrics_centralized {'accuracy': [(0, 0.0065625), (1, 0.074375), (2, 0.074375), (3, 0.060625), (4, 0.1490625), (5, 0.2046875), (6, 0.326875), (7, 0.4071875), (8, 0.48), (9, 0.5025), (10, 0.46875), (11, 0.5321875), (12, 0.540625), (13, 0.5565625), (14, 0.595625), (15, 0.5834375), (16, 0.5884375), (17, 0.60125), (18, 0.6071875), (19, 0.59625), (20, 0.58125), (21, 0.5153125), (22, 0.6321875), (23, 0.5625), (24, 0.61875), (25, 0.6615625), (26, 0.596875), (27, 0.6825), (28, 0.6271875), (29, 0.6484375), (30, 0.6353125), (31, 0.625), (32, 0.6584375), (33, 0.6671875), (34, 0.5946875), (35, 0.6640625), (36, 0.58375), (37, 0.6671875), (38, 0.6496875), (39, 0.6803125), (40, 0.5796875), (41, 0.6634375), (42, 0.6659375), (43, 0.6921875), (44, 0.68375), (45, 0.62), (46, 0.67125), (47, 0.6246875), (48, 0.6703125), (49, 0.64625), (50, 0.5859375)]}

# %% [markdown]
# 2. Build a function which reconstitutes the update that must have been applied to model $\theta^t$ in order to obtain $\theta^{t+1}$, assume the `server_learning_rate` was 1.0. We shall call this update $g_t$ and treat it as a pseudo-gradient.

# %%
def pseudoGradient(t, parameters_per_round):
    """
    Calculates the delta of model parameters applied
    at timestep t.
    """
    return [
      layer_t - layer_t_next
      for layer_t, layer_t_next
      in zip(parameters_per_round[t][1], parameters_per_round[t + 1][1])
      ]

# %%
def realGradient(t, parameters_per_round):
    """
    Calculates the delta of the model relative to its original weights
    at timestep t.
    """
    return [
      layer_t - layer_t_next
      for layer_t, layer_t_next
      in zip(parameters_per_round[t][1], parameters_per_round[-1][1])
      ]

# %% [markdown]
# 3. For each round plot the cosine similarity between $g_t$ and the direction of improvement towards $\theta^{*}$ calculated as $\theta^{*} - \theta_t$.

# %%
len(parameters_per_round)
# Out:
# 51

# %% [markdown]
# 4. What do you observe from the plots? Does every update point in the direction of the final model? If not, why do you think that is?

# %%
cosine_similarities = [
    cosineSimilarity(
        pseudoGradient(t, parameters_per_round),
        realGradient(t, parameters_per_round)
    )
    for t in range(len(parameters_per_round) - 1)
]

plt.figure(figsize=(12, 8))
sns.lineplot(data=cosine_similarities, marker='o')  # 'marker' adds points at each data value
plt.title("Cosine Similarity, Pseudo gradient vs Actual gradient")
plt.xlabel("Timestep")
plt.ylabel("Similarity")
plt.show()

# %% [markdown]
# From the plot, the similarities seem to increase quickly at the first few updates, plateau in the middle and spike towards the end, very nearly converging. However not all updates point in the direction of the final model, because the updates in the middle lead to decreased similarity sometimes.
#
# This might be because client data is heterogenous, causing some clients' training to proceed in different directions.

# %% [markdown]
# (c) 2024 Alexandru-Andrei Iacob, Lorenzo Sani
